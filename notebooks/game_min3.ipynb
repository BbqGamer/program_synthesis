# %% [markdown]
# # Now let's see how to add timelimit to the environment

# %% [markdown]
# After 4 steps the truncated is being set to True, indicating that the episode has ended due to the time limit.

# %% [markdown]
# Using a test Model

# %%
from stable_baselines3 import A2C, PPO
import gymnasium as gym
import assembly_game
from assembly_game.processor import PROCESSOR_ACTIONS

# %%
MAX_STEPS = 30
env = gym.make("Min3Game", max_episode_steps=MAX_STEPS)

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=200000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.6     |
# |    ep_rew_mean     | 1.07     |
# | time/              |          |
# |    fps             | 2887     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.4        |
# |    ep_rew_mean          | 1.12        |
# | time/                   |             |
# |    fps                  | 2119        |
# |    iterations           | 2           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015191071 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | -0.431      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.144       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0501     |
# |    value_loss           | 0.418       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 26.5       |
# |    ep_rew_mean          | 1.37       |
# | time/                   |            |
# |    fps                  | 1944       |
# |    iterations           | 3          |
# |    time_elapsed         | 3          |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01423497 |
# |    clip_fraction        | 0.154      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.3       |
# |    explained_variance   | 0.236      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0114     |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0504    |
# |    value_loss           | 0.289      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.1        |
# |    ep_rew_mean          | 1.35        |
# | time/                   |             |
# |    fps                  | 1847        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.015256501 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | 0.53        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00121     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.055      |
# |    value_loss           | 0.197       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.5        |
# |    ep_rew_mean          | 1.49        |
# | time/                   |             |
# |    fps                  | 1801        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013314559 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.54        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0477      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0488     |
# |    value_loss           | 0.279       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 1.71        |
# | time/                   |             |
# |    fps                  | 1775        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014433434 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.671       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0235      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0513     |
# |    value_loss           | 0.216       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.3        |
# |    ep_rew_mean          | 1.83        |
# | time/                   |             |
# |    fps                  | 1766        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013207002 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.718       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0139      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0474     |
# |    value_loss           | 0.202       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.8        |
# |    ep_rew_mean          | 1.82        |
# | time/                   |             |
# |    fps                  | 1755        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.016123116 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0115     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0558     |
# |    value_loss           | 0.124       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.9        |
# |    ep_rew_mean          | 1.98        |
# | time/                   |             |
# |    fps                  | 1748        |
# |    iterations           | 9           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.014410817 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.745       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0298     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0493     |
# |    value_loss           | 0.162       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.1        |
# |    ep_rew_mean          | 1.98        |
# | time/                   |             |
# |    fps                  | 1740        |
# |    iterations           | 10          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015307747 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.784       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00419    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0486     |
# |    value_loss           | 0.132       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15          |
# |    ep_rew_mean          | 1.92        |
# | time/                   |             |
# |    fps                  | 1732        |
# |    iterations           | 11          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.015225638 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.821       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0199     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0457     |
# |    value_loss           | 0.111       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.4        |
# |    ep_rew_mean          | 1.99        |
# | time/                   |             |
# |    fps                  | 1729        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013990624 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0441      |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0471     |
# |    value_loss           | 0.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.5        |
# |    ep_rew_mean          | 1.93        |
# | time/                   |             |
# |    fps                  | 1728        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.016528193 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.811       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.034      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0483     |
# |    value_loss           | 0.118       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.4        |
# |    ep_rew_mean          | 1.92        |
# | time/                   |             |
# |    fps                  | 1730        |
# |    iterations           | 14          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.015125553 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.742       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0233     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0483     |
# |    value_loss           | 0.145       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.7        |
# |    ep_rew_mean          | 1.89        |
# | time/                   |             |
# |    fps                  | 1732        |
# |    iterations           | 15          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.015197972 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0208     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0466     |
# |    value_loss           | 0.0805      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 17.4       |
# |    ep_rew_mean          | 2.1        |
# | time/                   |            |
# |    fps                  | 1733       |
# |    iterations           | 16         |
# |    time_elapsed         | 18         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.01404489 |
# |    clip_fraction        | 0.161      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4         |
# |    explained_variance   | 0.664      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00817    |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0468    |
# |    value_loss           | 0.152      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19           |
# |    ep_rew_mean          | 1.91         |
# | time/                   |              |
# |    fps                  | 1734         |
# |    iterations           | 17           |
# |    time_elapsed         | 20           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0141716935 |
# |    clip_fraction        | 0.168        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.02        |
# |    explained_variance   | 0.675        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00547     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.0482      |
# |    value_loss           | 0.109        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.3        |
# |    ep_rew_mean          | 2.11        |
# | time/                   |             |
# |    fps                  | 1735        |
# |    iterations           | 18          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.014018154 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.607       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0179     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0479     |
# |    value_loss           | 0.179       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.5        |
# |    ep_rew_mean          | 2.13        |
# | time/                   |             |
# |    fps                  | 1735        |
# |    iterations           | 19          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014895236 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0334     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0493     |
# |    value_loss           | 0.124       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.2        |
# |    ep_rew_mean          | 2.26        |
# | time/                   |             |
# |    fps                  | 1735        |
# |    iterations           | 20          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.017468128 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.681       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0178     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0501     |
# |    value_loss           | 0.126       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.7        |
# |    ep_rew_mean          | 2.49        |
# | time/                   |             |
# |    fps                  | 1734        |
# |    iterations           | 21          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.016921561 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0159      |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0496     |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.5        |
# |    ep_rew_mean          | 2.52        |
# | time/                   |             |
# |    fps                  | 1734        |
# |    iterations           | 22          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.015948087 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.88       |
# |    explained_variance   | 0.753       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00286     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0537     |
# |    value_loss           | 0.131       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.9        |
# |    ep_rew_mean          | 2.58        |
# | time/                   |             |
# |    fps                  | 1733        |
# |    iterations           | 23          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.015102448 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 0.756       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0144     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0503     |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.4        |
# |    ep_rew_mean          | 3.03        |
# | time/                   |             |
# |    fps                  | 1734        |
# |    iterations           | 24          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.016291374 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.755       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0217      |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0554     |
# |    value_loss           | 0.164       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.1        |
# |    ep_rew_mean          | 3.03        |
# | time/                   |             |
# |    fps                  | 1735        |
# |    iterations           | 25          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014889813 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.608       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0544      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0443     |
# |    value_loss           | 0.405       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.1        |
# |    ep_rew_mean          | 3.79        |
# | time/                   |             |
# |    fps                  | 1734        |
# |    iterations           | 26          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.015001841 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.768       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0141      |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0487     |
# |    value_loss           | 0.152       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.1         |
# |    ep_rew_mean          | 3.36         |
# | time/                   |              |
# |    fps                  | 1733         |
# |    iterations           | 27           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0076361448 |
# |    clip_fraction        | 0.0589       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.51        |
# |    explained_variance   | 0.0064       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.4         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0192      |
# |    value_loss           | 16           |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.5        |
# |    ep_rew_mean          | 3.26        |
# | time/                   |             |
# |    fps                  | 1733        |
# |    iterations           | 28          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.015635079 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.45       |
# |    explained_variance   | 0.542       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0444      |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0504     |
# |    value_loss           | 0.302       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.8        |
# |    ep_rew_mean          | 3.51        |
# | time/                   |             |
# |    fps                  | 1732        |
# |    iterations           | 29          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.013461734 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.35       |
# |    explained_variance   | 0.731       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00363    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0425     |
# |    value_loss           | 0.237       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.7        |
# |    ep_rew_mean          | 3.62        |
# | time/                   |             |
# |    fps                  | 1733        |
# |    iterations           | 30          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.016015593 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.24       |
# |    explained_variance   | 0.769       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00612    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0476     |
# |    value_loss           | 0.206       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.9        |
# |    ep_rew_mean          | 3.76        |
# | time/                   |             |
# |    fps                  | 1733        |
# |    iterations           | 31          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.023640916 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.025      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 0.132       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 14.7       |
# |    ep_rew_mean          | 3.82       |
# | time/                   |            |
# |    fps                  | 1733       |
# |    iterations           | 32         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 65536      |
# | train/                  |            |
# |    approx_kl            | 0.01506805 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.89      |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00186    |
# |    n_updates            | 310        |
# |    policy_gradient_loss | -0.0445    |
# |    value_loss           | 0.149      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.6        |
# |    ep_rew_mean          | 3.96        |
# | time/                   |             |
# |    fps                  | 1734        |
# |    iterations           | 33          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.014957095 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000877   |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0435     |
# |    value_loss           | 0.146       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 13.6       |
# |    ep_rew_mean          | 3.82       |
# | time/                   |            |
# |    fps                  | 1733       |
# |    iterations           | 34         |
# |    time_elapsed         | 40         |
# |    total_timesteps      | 69632      |
# | train/                  |            |
# |    approx_kl            | 0.01184788 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.63      |
# |    explained_variance   | 0.365      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.16       |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0246    |
# |    value_loss           | 1.66       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12.9        |
# |    ep_rew_mean          | 5.32        |
# | time/                   |             |
# |    fps                  | 1734        |
# |    iterations           | 35          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.018633567 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.036      |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0441     |
# |    value_loss           | 0.119       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.2        |
# |    ep_rew_mean          | 4.26        |
# | time/                   |             |
# |    fps                  | 1732        |
# |    iterations           | 36          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.019626517 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.49       |
# |    explained_variance   | 0.00228     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 53.8        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 57.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.1        |
# |    ep_rew_mean          | 4.28        |
# | time/                   |             |
# |    fps                  | 1731        |
# |    iterations           | 37          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.022969376 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0158     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0331     |
# |    value_loss           | 2.65        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.8        |
# |    ep_rew_mean          | 3.83        |
# | time/                   |             |
# |    fps                  | 1731        |
# |    iterations           | 38          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.011576767 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.65       |
# |    explained_variance   | 0.334       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.14        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0229     |
# |    value_loss           | 2.88        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.6        |
# |    ep_rew_mean          | 5.04        |
# | time/                   |             |
# |    fps                  | 1731        |
# |    iterations           | 39          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.019985167 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.851       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0448      |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0425     |
# |    value_loss           | 0.18        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 14.3        |
# |    ep_rew_mean          | 4.77        |
# | time/                   |             |
# |    fps                  | 1732        |
# |    iterations           | 40          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.007754176 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 0.0391      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.7        |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0171     |
# |    value_loss           | 20.2        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 16.9       |
# |    ep_rew_mean          | 6.3        |
# | time/                   |            |
# |    fps                  | 1732       |
# |    iterations           | 41         |
# |    time_elapsed         | 48         |
# |    total_timesteps      | 83968      |
# | train/                  |            |
# |    approx_kl            | 0.00838992 |
# |    clip_fraction        | 0.072      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.71      |
# |    explained_variance   | 0.144      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.63       |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0199    |
# |    value_loss           | 25.5       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 16.7        |
# |    ep_rew_mean          | 3.89        |
# | time/                   |             |
# |    fps                  | 1733        |
# |    iterations           | 42          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.004150196 |
# |    clip_fraction        | 0.022       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.8        |
# |    explained_variance   | 0.111       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.8        |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 69.3        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.6         |
# |    ep_rew_mean          | 8.23         |
# | time/                   |              |
# |    fps                  | 1734         |
# |    iterations           | 43           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0054355217 |
# |    clip_fraction        | 0.0384       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.89        |
# |    explained_variance   | 0.261        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.3         |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0188      |
# |    value_loss           | 40.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20.3         |
# |    ep_rew_mean          | 5.39         |
# | time/                   |              |
# |    fps                  | 1734         |
# |    iterations           | 44           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0037301015 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.98        |
# |    explained_variance   | 0.081        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 36.3         |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.0138      |
# |    value_loss           | 105          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.9        |
# |    ep_rew_mean          | 12.5        |
# | time/                   |             |
# |    fps                  | 1733        |
# |    iterations           | 45          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.008322049 |
# |    clip_fraction        | 0.0612      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.167       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 52.3        |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.0214     |
# |    value_loss           | 44.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.4         |
# |    ep_rew_mean          | 14.5         |
# | time/                   |              |
# |    fps                  | 1730         |
# |    iterations           | 46           |
# |    time_elapsed         | 54           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0038602154 |
# |    clip_fraction        | 0.00576      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | 0.122        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 206          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00882     |
# |    value_loss           | 265          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.4        |
# |    ep_rew_mean          | 13.5        |
# | time/                   |             |
# |    fps                  | 1727        |
# |    iterations           | 47          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.003809609 |
# |    clip_fraction        | 0.0103      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.12       |
# |    explained_variance   | 0.186       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 96.4        |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 269         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.9        |
# |    ep_rew_mean          | 26.5        |
# | time/                   |             |
# |    fps                  | 1722        |
# |    iterations           | 48          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.002528182 |
# |    clip_fraction        | 0.00293     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.177       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 27.6        |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00787    |
# |    value_loss           | 415         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 22          |
# | time/                   |             |
# |    fps                  | 1717        |
# |    iterations           | 49          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.002452631 |
# |    clip_fraction        | 0.0043      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.22        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 338         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00861    |
# |    value_loss           | 716         |
# -----------------------------------------

# %%
state, _ = env.reset()
cumreward = 0
for i in range(MAX_STEPS):
  action,_ = model.predict(state)
  state, reward, terminated, truncated, info = env.step(action)
  cumreward +=reward
  print(PROCESSOR_ACTIONS[action], info, reward)
  if terminated or truncated:
    print(terminated)
    print(truncated)
    print(f"Episode finished after {i+1} timestamps")
    break
print(f"total reward {cumreward}")
# Out:
# (<Instruction.MOV: 0>, <Operand.RDX: 2>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=0 cmp_res=0', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=0 cmp_res=0', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=0 cmp_res=0', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=0 cmp_res=0', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=0 cmp_res=0', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=0 cmp_res=0'} 2
# (<Instruction.MOV: 0>, <Operand.RSI: 1>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=2 cmp_res=0', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=3 cmp_res=0', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=0', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=0', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=0'} 0
# (<Instruction.CMP: 1>, <Operand.RDX: 2>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=2 cmp_res=-1', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=3 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=1 cmp_res=-2', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=2', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=-1', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=1'} 0
# (<Instruction.CMP: 1>, <Operand.RSI: 1>, <Operand.RDX: 2>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.MOV: 0>, <Operand.RAX: 4>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=3 rax=3 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=3 rax=3 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=2 rax=2 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=3 rax=3 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=3 rax=3 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=2 rax=2 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=3 rax=3 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=3 rax=3 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=2 rax=2 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=3 rax=3 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=3 rax=3 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=2 rax=2 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMP: 1>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=3 rax=3 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=3 rax=3 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=2 rax=2 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMOVG: 2>, <Operand.RDX: 2>, <Operand.RDX: 2>) {'example_0': 'rdi=1 rsi=3 rax=3 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=3 rax=3 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=2 rax=2 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMP: 1>, <Operand.RSI: 1>, <Operand.RDX: 2>) {'example_0': 'rdi=1 rsi=3 rax=3 rdx=3 rcx=2 cmp_res=0', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=0', 'example_2': 'rdi=2 rsi=3 rax=3 rdx=3 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=0', 'example_4': 'rdi=3 rsi=2 rax=2 rdx=2 rcx=1 cmp_res=0', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=0'} 0
# (<Instruction.MOV: 0>, <Operand.RCX: 3>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=2 cmp_res=0', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=3 cmp_res=0', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=0', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=0', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=0'} 0
# (<Instruction.CMP: 1>, <Operand.RAX: 4>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=2 cmp_res=0', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=3 cmp_res=0', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=0', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=0', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=0'} 0
# (<Instruction.CMP: 1>, <Operand.RSI: 1>, <Operand.RDX: 2>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=-1'} 2
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.MOV: 0>, <Operand.RAX: 4>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.MOV: 0>, <Operand.RCX: 3>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.MOV: 0>, <Operand.RCX: 3>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMOVG: 2>, <Operand.RDX: 2>, <Operand.RDX: 2>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=2', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1'} 0
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=3 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=-1', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=-2', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-2'} 0
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=2 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=1 rdx=2 rcx=3 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=-1', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=-2', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-2'} 12
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=-1', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=-2', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-2'} 10
# (<Instruction.MOV: 0>, <Operand.RDI: 0>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=2 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=1 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.MOV: 0>, <Operand.RDI: 0>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=2 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=3 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMP: 1>, <Operand.RCX: 3>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=3 rcx=1 cmp_res=0', 'example_1': 'rdi=1 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=0', 'example_2': 'rdi=2 rsi=2 rax=1 rdx=3 rcx=2 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=0', 'example_4': 'rdi=3 rsi=3 rax=1 rdx=2 rcx=3 cmp_res=0', 'example_5': 'rdi=3 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=0'} 10
# False
# True
# Episode finished after 30 timestamps
# total reward 56
