# %% [markdown]
# Using a test Model

# %%
from stable_baselines3 import PPO
import gymnasium as gym
import assembly_game
from assembly_game.processor import PROCESSOR_ACTIONS

# %%
MAX_STEPS = 30
env = gym.make("MinGame", max_episode_steps=MAX_STEPS, size = 3)

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=300000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/konstanty/STUDIA/masters_1_sem/program_synthesis/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.2     |
# |    ep_rew_mean     | 0.877    |
# | time/              |          |
# |    fps             | 1055     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.2        |
# |    ep_rew_mean          | 1.06        |
# | time/                   |             |
# |    fps                  | 852         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013248835 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | -0.0034     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0743      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.048      |
# |    value_loss           | 0.328       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.9        |
# |    ep_rew_mean          | 1.3         |
# | time/                   |             |
# |    fps                  | 821         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.011807263 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.294       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.06        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 0.381       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.9        |
# |    ep_rew_mean          | 1.53        |
# | time/                   |             |
# |    fps                  | 798         |
# |    iterations           | 4           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013251292 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0377      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0482     |
# |    value_loss           | 0.364       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.9        |
# |    ep_rew_mean          | 1.71        |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014241075 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | 0.566       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0463      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0537     |
# |    value_loss           | 0.264       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.8        |
# |    ep_rew_mean          | 2.16        |
# | time/                   |             |
# |    fps                  | 803         |
# |    iterations           | 6           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.015806008 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.612       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0508      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0556     |
# |    value_loss           | 0.233       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.5        |
# |    ep_rew_mean          | 2.38        |
# | time/                   |             |
# |    fps                  | 805         |
# |    iterations           | 7           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.010124703 |
# |    clip_fraction        | 0.0855      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.0531      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.37        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0255     |
# |    value_loss           | 8.46        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.2        |
# |    ep_rew_mean          | 1.66        |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 8           |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014764858 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.591       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.061       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0484     |
# |    value_loss           | 0.308       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25.6       |
# |    ep_rew_mean          | 1.96       |
# | time/                   |            |
# |    fps                  | 813        |
# |    iterations           | 9          |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01584772 |
# |    clip_fraction        | 0.188      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.18      |
# |    explained_variance   | 0.654      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.00639    |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0546    |
# |    value_loss           | 0.217      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.2        |
# |    ep_rew_mean          | 2.02        |
# | time/                   |             |
# |    fps                  | 815         |
# |    iterations           | 10          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.014621958 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.629       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0415      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0516     |
# |    value_loss           | 0.222       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.5        |
# |    ep_rew_mean          | 2.02        |
# | time/                   |             |
# |    fps                  | 813         |
# |    iterations           | 11          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014084939 |
# |    clip_fraction        | 0.157       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.65        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0107     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0478     |
# |    value_loss           | 0.188       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.2        |
# |    ep_rew_mean          | 1.99        |
# | time/                   |             |
# |    fps                  | 806         |
# |    iterations           | 12          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014153768 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.664       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00214     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0488     |
# |    value_loss           | 0.183       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.7        |
# |    ep_rew_mean          | 2           |
# | time/                   |             |
# |    fps                  | 799         |
# |    iterations           | 13          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014482804 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.712       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0414      |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0462     |
# |    value_loss           | 0.175       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.5        |
# |    ep_rew_mean          | 2.12        |
# | time/                   |             |
# |    fps                  | 795         |
# |    iterations           | 14          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014647407 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.791       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0589     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0494     |
# |    value_loss           | 0.0926      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.7        |
# |    ep_rew_mean          | 2.14        |
# | time/                   |             |
# |    fps                  | 786         |
# |    iterations           | 15          |
# |    time_elapsed         | 39          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.013947659 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.75        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0196     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 0.113       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28          |
# |    ep_rew_mean          | 2.14        |
# | time/                   |             |
# |    fps                  | 778         |
# |    iterations           | 16          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015168913 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.01       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0209     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.049      |
# |    value_loss           | 0.104       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.6        |
# |    ep_rew_mean          | 2.3         |
# | time/                   |             |
# |    fps                  | 754         |
# |    iterations           | 17          |
# |    time_elapsed         | 46          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014727841 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.96       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0387     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0467     |
# |    value_loss           | 0.104       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.7        |
# |    ep_rew_mean          | 2.3         |
# | time/                   |             |
# |    fps                  | 730         |
# |    iterations           | 18          |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.014724562 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.91       |
# |    explained_variance   | 0.817       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.03       |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0476     |
# |    value_loss           | 0.0926      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.3        |
# |    ep_rew_mean          | 2.26        |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 19          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.015097378 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.035       |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0479     |
# |    value_loss           | 0.155       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.4        |
# |    ep_rew_mean          | 2.39        |
# | time/                   |             |
# |    fps                  | 690         |
# |    iterations           | 20          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014601793 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.87       |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0528     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.051      |
# |    value_loss           | 0.12        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.3        |
# |    ep_rew_mean          | 2.44        |
# | time/                   |             |
# |    fps                  | 676         |
# |    iterations           | 21          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.015429713 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.842       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0556     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0519     |
# |    value_loss           | 0.0839      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.3        |
# |    ep_rew_mean          | 2.78        |
# | time/                   |             |
# |    fps                  | 663         |
# |    iterations           | 22          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.016088124 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.75       |
# |    explained_variance   | 0.826       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0143     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0481     |
# |    value_loss           | 0.108       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.8        |
# |    ep_rew_mean          | 3.38        |
# | time/                   |             |
# |    fps                  | 652         |
# |    iterations           | 23          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.012894809 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.277       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.92        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0325     |
# |    value_loss           | 1.48        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.4        |
# |    ep_rew_mean          | 2.97        |
# | time/                   |             |
# |    fps                  | 642         |
# |    iterations           | 24          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.012572548 |
# |    clip_fraction        | 0.132       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0326     |
# |    value_loss           | 1.51        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.3        |
# |    ep_rew_mean          | 2.82        |
# | time/                   |             |
# |    fps                  | 634         |
# |    iterations           | 25          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.015265439 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.643       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00681     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0469     |
# |    value_loss           | 0.237       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.2        |
# |    ep_rew_mean          | 4.44        |
# | time/                   |             |
# |    fps                  | 628         |
# |    iterations           | 26          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.015465096 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.754       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00454     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0478     |
# |    value_loss           | 0.19        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.9         |
# |    ep_rew_mean          | 3.94         |
# | time/                   |              |
# |    fps                  | 619          |
# |    iterations           | 27           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 55296        |
# | train/                  |              |
# |    approx_kl            | 0.0054690493 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.58        |
# |    explained_variance   | 0.0325       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.96         |
# |    n_updates            | 260          |
# |    policy_gradient_loss | -0.0161      |
# |    value_loss           | 22.9         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.3        |
# |    ep_rew_mean          | 4.52        |
# | time/                   |             |
# |    fps                  | 612         |
# |    iterations           | 28          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.016155677 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.523       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.134       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0492     |
# |    value_loss           | 0.484       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 28.8         |
# |    ep_rew_mean          | 4.29         |
# | time/                   |              |
# |    fps                  | 607          |
# |    iterations           | 29           |
# |    time_elapsed         | 97           |
# |    total_timesteps      | 59392        |
# | train/                  |              |
# |    approx_kl            | 0.0037439752 |
# |    clip_fraction        | 0.0131       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.57        |
# |    explained_variance   | 0.0596       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.83         |
# |    n_updates            | 280          |
# |    policy_gradient_loss | -0.00967     |
# |    value_loss           | 31.1         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.3       |
# |    ep_rew_mean          | 6.96       |
# | time/                   |            |
# |    fps                  | 602        |
# |    iterations           | 30         |
# |    time_elapsed         | 101        |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00721037 |
# |    clip_fraction        | 0.0474     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.53      |
# |    explained_variance   | 0.0777     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.29       |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0165    |
# |    value_loss           | 24         |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.7         |
# |    ep_rew_mean          | 4.1          |
# | time/                   |              |
# |    fps                  | 599          |
# |    iterations           | 31           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0035982833 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.55        |
# |    explained_variance   | 0.0679       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 135          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 129          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.4        |
# |    ep_rew_mean          | 7.78        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 32          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008915989 |
# |    clip_fraction        | 0.0997      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.52       |
# |    explained_variance   | 0.133       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.646       |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0209     |
# |    value_loss           | 16          |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.6         |
# |    ep_rew_mean          | 11           |
# | time/                   |              |
# |    fps                  | 592          |
# |    iterations           | 33           |
# |    time_elapsed         | 114          |
# |    total_timesteps      | 67584        |
# | train/                  |              |
# |    approx_kl            | 0.0034338194 |
# |    clip_fraction        | 0.00791      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.52        |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 98.7         |
# |    n_updates            | 320          |
# |    policy_gradient_loss | -0.00855     |
# |    value_loss           | 98           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.7         |
# |    ep_rew_mean          | 9.84         |
# | time/                   |              |
# |    fps                  | 589          |
# |    iterations           | 34           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 69632        |
# | train/                  |              |
# |    approx_kl            | 0.0025918097 |
# |    clip_fraction        | 0.00664      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.5         |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 64.2         |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -0.0083      |
# |    value_loss           | 188          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.8         |
# |    ep_rew_mean          | 7.17         |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 35           |
# |    time_elapsed         | 122          |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0028713187 |
# |    clip_fraction        | 0.00376      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.53        |
# |    explained_variance   | 0.2          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 74.9         |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -0.00997     |
# |    value_loss           | 148          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.8         |
# |    ep_rew_mean          | 15           |
# | time/                   |              |
# |    fps                  | 583          |
# |    iterations           | 36           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0039384086 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.48        |
# |    explained_variance   | 0.235        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 41.3         |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0114      |
# |    value_loss           | 98.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.6         |
# |    ep_rew_mean          | 15.2         |
# | time/                   |              |
# |    fps                  | 581          |
# |    iterations           | 37           |
# |    time_elapsed         | 130          |
# |    total_timesteps      | 75776        |
# | train/                  |              |
# |    approx_kl            | 0.0034385049 |
# |    clip_fraction        | 0.004        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.49        |
# |    explained_variance   | 0.193        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 281          |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -0.00757     |
# |    value_loss           | 382          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.3         |
# |    ep_rew_mean          | 22.9         |
# | time/                   |              |
# |    fps                  | 579          |
# |    iterations           | 38           |
# |    time_elapsed         | 134          |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0033937409 |
# |    clip_fraction        | 0.00718      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.44        |
# |    explained_variance   | 0.26         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 57.1         |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00861     |
# |    value_loss           | 206          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.4        |
# |    ep_rew_mean          | 17.5        |
# | time/                   |             |
# |    fps                  | 577         |
# |    iterations           | 39          |
# |    time_elapsed         | 138         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.003812727 |
# |    clip_fraction        | 0.00605     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.43       |
# |    explained_variance   | 0.209       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 219         |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00909    |
# |    value_loss           | 547         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.6         |
# |    ep_rew_mean          | 12.8         |
# | time/                   |              |
# |    fps                  | 575          |
# |    iterations           | 40           |
# |    time_elapsed         | 142          |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0045909295 |
# |    clip_fraction        | 0.02         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.42        |
# |    explained_variance   | 0.315        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 189          |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.0134      |
# |    value_loss           | 300          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.6         |
# |    ep_rew_mean          | 26.2         |
# | time/                   |              |
# |    fps                  | 573          |
# |    iterations           | 41           |
# |    time_elapsed         | 146          |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0033591068 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.37        |
# |    explained_variance   | 0.267        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 99.5         |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0122      |
# |    value_loss           | 218          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.6         |
# |    ep_rew_mean          | 33.6         |
# | time/                   |              |
# |    fps                  | 577          |
# |    iterations           | 42           |
# |    time_elapsed         | 148          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0036216192 |
# |    clip_fraction        | 0.00937      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.33        |
# |    explained_variance   | 0.256        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 284          |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.00862     |
# |    value_loss           | 738          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.8         |
# |    ep_rew_mean          | 37.8         |
# | time/                   |              |
# |    fps                  | 582          |
# |    iterations           | 43           |
# |    time_elapsed         | 151          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0033730562 |
# |    clip_fraction        | 0.00811      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.35        |
# |    explained_variance   | 0.344        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 510          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00819     |
# |    value_loss           | 836          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.3         |
# |    ep_rew_mean          | 27           |
# | time/                   |              |
# |    fps                  | 586          |
# |    iterations           | 44           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0046641687 |
# |    clip_fraction        | 0.0144       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.26        |
# |    explained_variance   | 0.375        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 241          |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00956     |
# |    value_loss           | 810          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.6         |
# |    ep_rew_mean          | 40.2         |
# | time/                   |              |
# |    fps                  | 590          |
# |    iterations           | 45           |
# |    time_elapsed         | 155          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0039070733 |
# |    clip_fraction        | 0.00859      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.2         |
# |    explained_variance   | 0.371        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 189          |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.00955     |
# |    value_loss           | 771          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 51.7        |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 46          |
# |    time_elapsed         | 158         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.004391296 |
# |    clip_fraction        | 0.0227      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.361       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 546         |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 930         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 59.8        |
# | time/                   |             |
# |    fps                  | 599         |
# |    iterations           | 47          |
# |    time_elapsed         | 160         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.004107131 |
# |    clip_fraction        | 0.00879     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.14       |
# |    explained_variance   | 0.437       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 596         |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 1.23e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 71.6        |
# | time/                   |             |
# |    fps                  | 602         |
# |    iterations           | 48          |
# |    time_elapsed         | 163         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.004974606 |
# |    clip_fraction        | 0.00928     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 453         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 1.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 85.5        |
# | time/                   |             |
# |    fps                  | 606         |
# |    iterations           | 49          |
# |    time_elapsed         | 165         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.007194968 |
# |    clip_fraction        | 0.0267      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.97       |
# |    explained_variance   | 0.378       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 586         |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 1.69e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 95.1        |
# | time/                   |             |
# |    fps                  | 609         |
# |    iterations           | 50          |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.008690191 |
# |    clip_fraction        | 0.0587      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.37        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 842         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0172     |
# |    value_loss           | 1.66e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 94.9         |
# | time/                   |              |
# |    fps                  | 613          |
# |    iterations           | 51           |
# |    time_elapsed         | 170          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0058277426 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.398        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.04e+03     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0136      |
# |    value_loss           | 2.03e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 98.7        |
# | time/                   |             |
# |    fps                  | 616         |
# |    iterations           | 52          |
# |    time_elapsed         | 172         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.008035853 |
# |    clip_fraction        | 0.0569      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 778         |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 1.87e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 113         |
# | time/                   |             |
# |    fps                  | 619         |
# |    iterations           | 53          |
# |    time_elapsed         | 175         |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.008873308 |
# |    clip_fraction        | 0.0656      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.414       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 840         |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 2.2e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.7         |
# |    ep_rew_mean          | 142          |
# | time/                   |              |
# |    fps                  | 622          |
# |    iterations           | 54           |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0072238576 |
# |    clip_fraction        | 0.0474       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.45        |
# |    explained_variance   | 0.412        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.25e+03     |
# |    n_updates            | 530          |
# ...
# |    ep_len_mean          | 29.8         |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 683          |
# |    iterations           | 81           |
# |    time_elapsed         | 242          |
# |    total_timesteps      | 165888       |
# | train/                  |              |
# |    approx_kl            | 0.0058462503 |
# |    clip_fraction        | 0.0818       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.26        |
# |    explained_variance   | 0.293        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.71e+03     |
# |    n_updates            | 800          |
# |    policy_gradient_loss | -0.00896     |
# |    value_loss           | 4.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 684          |
# |    iterations           | 82           |
# |    time_elapsed         | 245          |
# |    total_timesteps      | 167936       |
# | train/                  |              |
# |    approx_kl            | 0.0076496764 |
# |    clip_fraction        | 0.0827       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.39        |
# |    explained_variance   | 0.426        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.7e+03      |
# |    n_updates            | 810          |
# |    policy_gradient_loss | -0.0156      |
# |    value_loss           | 3.76e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 686         |
# |    iterations           | 83          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.007897733 |
# |    clip_fraction        | 0.0964      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | 0.445       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.99e+03    |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 3.91e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 247          |
# | time/                   |              |
# |    fps                  | 688          |
# |    iterations           | 84           |
# |    time_elapsed         | 249          |
# |    total_timesteps      | 172032       |
# | train/                  |              |
# |    approx_kl            | 0.0074302186 |
# |    clip_fraction        | 0.0764       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.4          |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.51e+03     |
# |    n_updates            | 830          |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 3.72e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 689          |
# |    iterations           | 85           |
# |    time_elapsed         | 252          |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 0.0049442416 |
# |    clip_fraction        | 0.066        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.12        |
# |    explained_variance   | 0.469        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.82e+03     |
# |    n_updates            | 840          |
# |    policy_gradient_loss | -0.0106      |
# |    value_loss           | 3.77e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 86          |
# |    time_elapsed         | 254         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.008750376 |
# |    clip_fraction        | 0.0809      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.18        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.79e+03    |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 3.61e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 254         |
# | time/                   |             |
# |    fps                  | 692         |
# |    iterations           | 87          |
# |    time_elapsed         | 257         |
# |    total_timesteps      | 178176      |
# | train/                  |             |
# |    approx_kl            | 0.027073178 |
# |    clip_fraction        | 0.0922      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.17       |
# |    explained_variance   | 0.00234     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.52e+03    |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 3.5e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 694         |
# |    iterations           | 88          |
# |    time_elapsed         | 259         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.008743878 |
# |    clip_fraction        | 0.086       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.00156     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.49e+03    |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 3.46e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 89          |
# |    time_elapsed         | 262         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.006565322 |
# |    clip_fraction        | 0.0748      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.3         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.27e+03    |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 3.61e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 252         |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 90          |
# |    time_elapsed         | 264         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.008408107 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.365       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.38e+03    |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 3.53e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 253         |
# | time/                   |             |
# |    fps                  | 697         |
# |    iterations           | 91          |
# |    time_elapsed         | 267         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.005350502 |
# |    clip_fraction        | 0.0631      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.898      |
# |    explained_variance   | 0.0249      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33e+03    |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 3.17e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 699          |
# |    iterations           | 92           |
# |    time_elapsed         | 269          |
# |    total_timesteps      | 188416       |
# | train/                  |              |
# |    approx_kl            | 0.0059644654 |
# |    clip_fraction        | 0.0889       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.974       |
# |    explained_variance   | 0.00938      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.4e+03      |
# |    n_updates            | 910          |
# |    policy_gradient_loss | -0.00827     |
# |    value_loss           | 3.49e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 249         |
# | time/                   |             |
# |    fps                  | 700         |
# |    iterations           | 93          |
# |    time_elapsed         | 271         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.009635247 |
# |    clip_fraction        | 0.0967      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.2        |
# |    explained_variance   | 2.04e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33e+03    |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 3.08e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 248          |
# | time/                   |              |
# |    fps                  | 701          |
# |    iterations           | 94           |
# |    time_elapsed         | 274          |
# |    total_timesteps      | 192512       |
# | train/                  |              |
# |    approx_kl            | 0.0051437374 |
# |    clip_fraction        | 0.0744       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.13        |
# |    explained_variance   | 0.349        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.7e+03      |
# |    n_updates            | 930          |
# |    policy_gradient_loss | -0.0142      |
# |    value_loss           | 3.09e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 252          |
# | time/                   |              |
# |    fps                  | 703          |
# |    iterations           | 95           |
# |    time_elapsed         | 276          |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 0.0068384986 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.778       |
# |    explained_variance   | 0.242        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.53e+03     |
# |    n_updates            | 940          |
# |    policy_gradient_loss | -0.0101      |
# |    value_loss           | 3.12e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 250         |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 96          |
# |    time_elapsed         | 279         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.005992952 |
# |    clip_fraction        | 0.0489      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.879      |
# |    explained_variance   | 3.76e-06    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33e+03    |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00736    |
# |    value_loss           | 2.88e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 97          |
# |    time_elapsed         | 281         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.004809409 |
# |    clip_fraction        | 0.0548      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.99       |
# |    explained_variance   | 0.142       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.27e+03    |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0134     |
# |    value_loss           | 2.86e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 251          |
# | time/                   |              |
# |    fps                  | 707          |
# |    iterations           | 98           |
# |    time_elapsed         | 283          |
# |    total_timesteps      | 200704       |
# | train/                  |              |
# |    approx_kl            | 0.0056293462 |
# |    clip_fraction        | 0.0597       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.879       |
# |    explained_variance   | 0.192        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.43e+03     |
# |    n_updates            | 970          |
# |    policy_gradient_loss | -0.0135      |
# |    value_loss           | 2.93e+03     |
# ------------------------------------------

# %%
state, _ = env.reset()
cumreward = 0
for i in range(MAX_STEPS):
  action,_ = model.predict(state)
  state, reward, terminated, truncated, info = env.step(action)
  cumreward +=reward
  print(PROCESSOR_ACTIONS[action], info, reward)
  if terminated or truncated:
    print(terminated)
    print(truncated)
    print(f"Episode finished after {i+1} timestamps")
    break
print(f"total reward {cumreward}")
# Out:
# (<Instruction.MOV: 0>, <Operand.RDX: 2>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=0 cmp_res=0', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=0 cmp_res=0', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=0 cmp_res=0', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=0 cmp_res=0', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=0 cmp_res=0', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=0 cmp_res=0'} 2
# (<Instruction.CMP: 1>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=0 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=0 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=0 cmp_res=2', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=0 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=0 cmp_res=1', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=0 cmp_res=-1'} 0
# (<Instruction.MOV: 0>, <Operand.RDI: 0>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=1 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=2 cmp_res=2', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=3 cmp_res=1', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-1'} 0
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=1 cmp_res=-1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=2', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-2', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=1', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-1'} 2
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 0
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 12
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=1 cmp_res=1', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=1 cmp_res=1', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=2 cmp_res=-1', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=2 cmp_res=-1', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=3 cmp_res=-2', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=3 cmp_res=-2'} 10
# False
# True
# Episode finished after 30 timestamps
# total reward 256
