# %% [markdown]
# Using a test Model

# %%
from stable_baselines3 import PPO
import gymnasium as gym
import assembly_game
from assembly_game.processor import PROCESSOR_ACTIONS

# %%
MAX_STEPS = 30
env = gym.make("MinGame", max_episode_steps=MAX_STEPS, size = 3)

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=300000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/konstanty/STUDIA/masters_1_sem/program_synthesis/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 23.8     |
# |    ep_rew_mean     | 1.06     |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 1045     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.8       |
# |    ep_rew_mean          | 1.02       |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 682        |
# |    iterations           | 2          |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 4096       |
# | train/                  |            |
# |    approx_kl            | 0.01295853 |
# |    clip_fraction        | 0.164      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.32      |
# |    explained_variance   | 0.116      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0278     |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0452    |
# |    value_loss           | 0.354      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27          |
# |    ep_rew_mean          | 1.15        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 595         |
# |    iterations           | 3           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013371933 |
# |    clip_fraction        | 0.154       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.372       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0711      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0501     |
# |    value_loss           | 0.316       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.9        |
# |    ep_rew_mean          | 1.51        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 566         |
# |    iterations           | 4           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013383282 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.424       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.000219    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.05       |
# |    value_loss           | 0.269       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.6        |
# |    ep_rew_mean          | 1.71        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 557         |
# |    iterations           | 5           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.014883812 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.28       |
# |    explained_variance   | 0.606       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0633      |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0516     |
# |    value_loss           | 0.221       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 24.4       |
# |    ep_rew_mean          | 1.76       |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 554        |
# |    iterations           | 6          |
# |    time_elapsed         | 22         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01596521 |
# |    clip_fraction        | 0.194      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.25      |
# |    explained_variance   | 0.742      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0263    |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0524    |
# |    value_loss           | 0.156      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.6        |
# |    ep_rew_mean          | 1.76        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 549         |
# |    iterations           | 7           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.014764902 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.692       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0305      |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0494     |
# |    value_loss           | 0.195       |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 22.5      |
# |    ep_rew_mean          | 1.85      |
# |    success_rate         | 0         |
# | time/                   |           |
# |    fps                  | 548       |
# |    iterations           | 8         |
# |    time_elapsed         | 29        |
# |    total_timesteps      | 16384     |
# | train/                  |           |
# |    approx_kl            | 0.0178276 |
# |    clip_fraction        | 0.209     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -4.2      |
# |    explained_variance   | 0.756     |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.0255   |
# |    n_updates            | 70        |
# |    policy_gradient_loss | -0.0514   |
# |    value_loss           | 0.147     |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.3        |
# |    ep_rew_mean          | 1.9         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 547         |
# |    iterations           | 9           |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015451532 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.77        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0161     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0467     |
# |    value_loss           | 0.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 17.9        |
# |    ep_rew_mean          | 1.97        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 10          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016117824 |
# |    clip_fraction        | 0.203       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.13       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0376     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0497     |
# |    value_loss           | 0.106       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.7        |
# |    ep_rew_mean          | 1.92        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 11          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014035974 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.1        |
# |    explained_variance   | 0.815       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.000179   |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 0.0976      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.7        |
# |    ep_rew_mean          | 2           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 12          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014175354 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.05       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.02       |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0439     |
# |    value_loss           | 0.112       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 15.2        |
# |    ep_rew_mean          | 1.86        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 13          |
# |    time_elapsed         | 48          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015160657 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.848       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0287     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 0.0823      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.2        |
# |    ep_rew_mean          | 1.99        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 546         |
# |    iterations           | 14          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014734152 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.727       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0197     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0446     |
# |    value_loss           | 0.145       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 11.9        |
# |    ep_rew_mean          | 1.92        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 545         |
# |    iterations           | 15          |
# |    time_elapsed         | 56          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.016169073 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.05       |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0441     |
# |    value_loss           | 0.0686      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 12          |
# |    ep_rew_mean          | 1.95        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 541         |
# |    iterations           | 16          |
# |    time_elapsed         | 60          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.014253804 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0499     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0432     |
# |    value_loss           | 0.0878      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10.5        |
# |    ep_rew_mean          | 1.96        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 17          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014535632 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.792       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.035      |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 0.111       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.97        |
# |    ep_rew_mean          | 2           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 538         |
# |    iterations           | 18          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015698656 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0379     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 0.0701      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.42        |
# |    ep_rew_mean          | 2.01        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 536         |
# |    iterations           | 19          |
# |    time_elapsed         | 72          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.013696029 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0258      |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0403     |
# |    value_loss           | 0.102       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 7.2         |
# |    ep_rew_mean          | 1.99        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 535         |
# |    iterations           | 20          |
# |    time_elapsed         | 76          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.016042957 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.889       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0601     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 0.0554      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.46        |
# |    ep_rew_mean          | 1.97        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 534         |
# |    iterations           | 21          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.016412333 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.51       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0389     |
# |    value_loss           | 0.0329      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.39        |
# |    ep_rew_mean          | 1.96        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 535         |
# |    iterations           | 22          |
# |    time_elapsed         | 84          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.015335403 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.885       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.032      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.037      |
# |    value_loss           | 0.0434      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.94        |
# |    ep_rew_mean          | 2           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 532         |
# |    iterations           | 23          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.017499957 |
# |    clip_fraction        | 0.227       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0486     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0367     |
# |    value_loss           | 0.0456      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.4         |
# |    ep_rew_mean          | 2           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 531         |
# |    iterations           | 24          |
# |    time_elapsed         | 92          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.014338249 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0514     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0373     |
# |    value_loss           | 0.0313      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.8         |
# |    ep_rew_mean          | 1.99        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 531         |
# |    iterations           | 25          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012133561 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.94       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0326     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0355     |
# |    value_loss           | 0.0193      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.99        |
# |    ep_rew_mean          | 2.01        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 530         |
# |    iterations           | 26          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.013447785 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.89       |
# |    explained_variance   | 0.97        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0273     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.033      |
# |    value_loss           | 0.0187      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.49        |
# |    ep_rew_mean          | 2.03        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 528         |
# |    iterations           | 27          |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.015854985 |
# |    clip_fraction        | 0.164       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0413     |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0356     |
# |    value_loss           | 0.0377      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.85        |
# |    ep_rew_mean          | 1.99        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 525         |
# |    iterations           | 28          |
# |    time_elapsed         | 109         |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.011572387 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0288     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.032      |
# |    value_loss           | 0.0497      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 4.94        |
# |    ep_rew_mean          | 2.03        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 525         |
# |    iterations           | 29          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.014939499 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.058      |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0357     |
# |    value_loss           | 0.0176      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.7         |
# |    ep_rew_mean          | 1.98        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 524         |
# |    iterations           | 30          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013473321 |
# |    clip_fraction        | 0.152       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.93       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0322     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0288     |
# |    value_loss           | 0.0395      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 5.8         |
# |    ep_rew_mean          | 2.1         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 524         |
# |    iterations           | 31          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.013669144 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3          |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0525     |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0311     |
# |    value_loss           | 0.0554      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.25        |
# |    ep_rew_mean          | 2.09        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 524         |
# |    iterations           | 32          |
# |    time_elapsed         | 124         |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.024217367 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.06       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0106      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0371     |
# |    value_loss           | 0.111       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 6.63        |
# |    ep_rew_mean          | 2.18        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 33          |
# |    time_elapsed         | 128         |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.016847223 |
# |    clip_fraction        | 0.258       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.09       |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0841      |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0458     |
# |    value_loss           | 0.21        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.15        |
# |    ep_rew_mean          | 2.35        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 523         |
# |    iterations           | 34          |
# |    time_elapsed         | 133         |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.016050138 |
# |    clip_fraction        | 0.265       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.05       |
# |    explained_variance   | 0.683       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0819      |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0474     |
# |    value_loss           | 0.227       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.45        |
# |    ep_rew_mean          | 2.67        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 522         |
# |    iterations           | 35          |
# |    time_elapsed         | 137         |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.017068192 |
# |    clip_fraction        | 0.294       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.11       |
# |    explained_variance   | 0.641       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.076       |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0547     |
# |    value_loss           | 0.274       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.97         |
# |    ep_rew_mean          | 2.91         |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 522          |
# |    iterations           | 36           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0146669345 |
# |    clip_fraction        | 0.217        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.0614       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.657        |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0366      |
# |    value_loss           | 6.11         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9.01       |
# |    ep_rew_mean          | 3.06       |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 521        |
# |    iterations           | 37         |
# |    time_elapsed         | 145        |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.01760069 |
# |    clip_fraction        | 0.253      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.91      |
# |    explained_variance   | 0.562      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.281      |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.0524    |
# |    value_loss           | 0.496      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.08        |
# |    ep_rew_mean          | 3.49        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 521         |
# |    iterations           | 38          |
# |    time_elapsed         | 149         |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.014509662 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.0792      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.53        |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0295     |
# |    value_loss           | 8.34        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.66        |
# |    ep_rew_mean          | 3.73        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 521         |
# |    iterations           | 39          |
# |    time_elapsed         | 153         |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.021496996 |
# |    clip_fraction        | 0.314       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.658       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.107       |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.059      |
# |    value_loss           | 0.385       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 9          |
# |    ep_rew_mean          | 3.84       |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 520        |
# |    iterations           | 40         |
# |    time_elapsed         | 157        |
# |    total_timesteps      | 81920      |
# | train/                  |            |
# |    approx_kl            | 0.02058255 |
# |    clip_fraction        | 0.266      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.59      |
# |    explained_variance   | 0.846      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0753     |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0483    |
# |    value_loss           | 0.21       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 8.13        |
# |    ep_rew_mean          | 4.96        |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 520         |
# |    iterations           | 41          |
# |    time_elapsed         | 161         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.012438867 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.0378      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.178       |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 28.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 8.29         |
# |    ep_rew_mean          | 4.13         |
# |    success_rate         | 0.01         |
# | time/                   |              |
# |    fps                  | 518          |
# |    iterations           | 42           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0072222752 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.31        |
# |    explained_variance   | 0.045        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 31.5         |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0207      |
# |    value_loss           | 20.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.6         |
# |    ep_rew_mean          | 3.88        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 518         |
# |    iterations           | 43          |
# |    time_elapsed         | 169         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.010385023 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.33       |
# |    explained_variance   | 0.0855      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.411       |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0226     |
# |    value_loss           | 13.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 9.04        |
# |    ep_rew_mean          | 5.15        |
# |    success_rate         | 0.02        |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 44          |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.004603152 |
# |    clip_fraction        | 0.0327      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.024       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 97          |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00997    |
# |    value_loss           | 151         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 11.6         |
# |    ep_rew_mean          | 3.84         |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 516          |
# |    iterations           | 45           |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 92160        |
# | train/                  |              |
# |    approx_kl            | 0.0055899275 |
# |    clip_fraction        | 0.0709       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.56        |
# |    explained_variance   | 0.061        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 61           |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -0.0167      |
# |    value_loss           | 157          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 13.1        |
# |    ep_rew_mean          | 9.75        |
# |    success_rate         | 0.06        |
# | time/                   |             |
# |    fps                  | 516         |
# |    iterations           | 46          |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.012115872 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.0156      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.29        |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.03       |
# |    value_loss           | 12.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 16.8         |
# |    ep_rew_mean          | 21.3         |
# |    success_rate         | 0.17         |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 47           |
# |    time_elapsed         | 186          |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0045855856 |
# |    clip_fraction        | 0.0242       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.83        |
# |    explained_variance   | 0.0746       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 60.9         |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0124      |
# |    value_loss           | 245          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.1         |
# |    ep_rew_mean          | 18.6         |
# |    success_rate         | 0.16         |
# | time/                   |              |
# |    fps                  | 515          |
# |    iterations           | 48           |
# |    time_elapsed         | 190          |
# |    total_timesteps      | 98304        |
# | train/                  |              |
# |    approx_kl            | 0.0045329547 |
# |    clip_fraction        | 0.0228       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.01        |
# |    explained_variance   | 0.106        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 263          |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -0.0126      |
# |    value_loss           | 569          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 21.6         |
# |    ep_rew_mean          | 26.6         |
# |    success_rate         | 0.22         |
# | time/                   |              |
# |    fps                  | 514          |
# |    iterations           | 49           |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0055919755 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.02        |
# |    explained_variance   | 0.114        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 94.1         |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0152      |
# |    value_loss           | 477          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.6         |
# |    ep_rew_mean          | 29.1         |
# |    success_rate         | 0.24         |
# | time/                   |              |
# |    fps                  | 513          |
# |    iterations           | 50           |
# |    time_elapsed         | 199          |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0038065028 |
# |    clip_fraction        | 0.0132       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.07        |
# |    explained_variance   | 0.161        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 303          |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00968     |
# |    value_loss           | 779          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.3         |
# |    ep_rew_mean          | 33.8         |
# |    success_rate         | 0.3          |
# | time/                   |              |
# |    fps                  | 512          |
# |    iterations           | 51           |
# |    time_elapsed         | 203          |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0030553243 |
# |    clip_fraction        | 0.00532      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.05        |
# |    explained_variance   | 0.17         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 266          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00953     |
# |    value_loss           | 909          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.8        |
# |    ep_rew_mean          | 34.7        |
# |    success_rate         | 0.31        |
# | time/                   |             |
# |    fps                  | 512         |
# |    iterations           | 52          |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.003775003 |
# |    clip_fraction        | 0.0115      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.01       |
# ...
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 253          |
# |    success_rate         | 0.99         |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 131          |
# |    time_elapsed         | 527          |
# |    total_timesteps      | 268288       |
# | train/                  |              |
# |    approx_kl            | 0.0036014803 |
# |    clip_fraction        | 0.0313       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.211       |
# |    explained_variance   | 1.34e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 650          |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | -0.00841     |
# |    value_loss           | 1.54e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 253          |
# |    success_rate         | 0.99         |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 132          |
# |    time_elapsed         | 531          |
# |    total_timesteps      | 270336       |
# | train/                  |              |
# |    approx_kl            | 0.0012013767 |
# |    clip_fraction        | 0.0167       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.203       |
# |    explained_variance   | 0.0914       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 601          |
# |    n_updates            | 1310         |
# |    policy_gradient_loss | -0.00731     |
# |    value_loss           | 1.48e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 253          |
# |    success_rate         | 0.99         |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 133          |
# |    time_elapsed         | 535          |
# |    total_timesteps      | 272384       |
# | train/                  |              |
# |    approx_kl            | 0.0017779854 |
# |    clip_fraction        | 0.0152       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.179       |
# |    explained_variance   | 1.91e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 604          |
# |    n_updates            | 1320         |
# |    policy_gradient_loss | -0.00284     |
# |    value_loss           | 1.42e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 252          |
# |    success_rate         | 0.99         |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 134          |
# |    time_elapsed         | 539          |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0027817485 |
# |    clip_fraction        | 0.0196       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.119       |
# |    explained_variance   | 0.435        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 575          |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.00847     |
# |    value_loss           | 1.41e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 256          |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 135          |
# |    time_elapsed         | 543          |
# |    total_timesteps      | 276480       |
# | train/                  |              |
# |    approx_kl            | 0.0015478849 |
# |    clip_fraction        | 0.0185       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.158       |
# |    explained_variance   | 0.217        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 569          |
# |    n_updates            | 1340         |
# |    policy_gradient_loss | -0.00836     |
# |    value_loss           | 1.35e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 253          |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 136          |
# |    time_elapsed         | 547          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0014256816 |
# |    clip_fraction        | 0.0189       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.077       |
# |    explained_variance   | 0.000114     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 542          |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.00189     |
# |    value_loss           | 1.29e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 255         |
# |    success_rate         | 1           |
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 137         |
# |    time_elapsed         | 551         |
# |    total_timesteps      | 280576      |
# | train/                  |             |
# |    approx_kl            | 0.002609635 |
# |    clip_fraction        | 0.0306      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.13       |
# |    explained_variance   | 2.57e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 531         |
# |    n_updates            | 1360        |
# |    policy_gradient_loss | -0.00673    |
# |    value_loss           | 1.25e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 256          |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 138          |
# |    time_elapsed         | 555          |
# |    total_timesteps      | 282624       |
# | train/                  |              |
# |    approx_kl            | 0.0018993203 |
# |    clip_fraction        | 0.0229       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.111       |
# |    explained_variance   | 1.83e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 487          |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.000891    |
# |    value_loss           | 1.2e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 253          |
# |    success_rate         | 0.99         |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 139          |
# |    time_elapsed         | 559          |
# |    total_timesteps      | 284672       |
# | train/                  |              |
# |    approx_kl            | 0.0018330989 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.164       |
# |    explained_variance   | 1.6e-05      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 533          |
# |    n_updates            | 1380         |
# |    policy_gradient_loss | -0.00228     |
# |    value_loss           | 1.17e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 256          |
# |    success_rate         | 1            |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 140          |
# |    time_elapsed         | 563          |
# |    total_timesteps      | 286720       |
# | train/                  |              |
# |    approx_kl            | 0.0024882522 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.211       |
# |    explained_variance   | 0.00671      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 470          |
# |    n_updates            | 1390         |
# |    policy_gradient_loss | -0.00381     |
# |    value_loss           | 1.14e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 251          |
# |    success_rate         | 0.99         |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 141          |
# |    time_elapsed         | 567          |
# |    total_timesteps      | 288768       |
# | train/                  |              |
# |    approx_kl            | 0.0014337545 |
# |    clip_fraction        | 0.00991      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.139       |
# |    explained_variance   | 6.37e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 468          |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 1.08e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 252          |
# |    success_rate         | 0.99         |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 142          |
# |    time_elapsed         | 571          |
# |    total_timesteps      | 290816       |
# | train/                  |              |
# |    approx_kl            | 0.0034801103 |
# |    clip_fraction        | 0.0335       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.194       |
# |    explained_variance   | 0.214        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 455          |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.00524     |
# |    value_loss           | 1.06e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 238          |
# |    success_rate         | 0.94         |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 143          |
# |    time_elapsed         | 575          |
# |    total_timesteps      | 292864       |
# | train/                  |              |
# |    approx_kl            | 0.0023780572 |
# |    clip_fraction        | 0.0168       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.145       |
# |    explained_variance   | 2.91e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 437          |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | -0.00316     |
# |    value_loss           | 1e+03        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 239         |
# |    success_rate         | 0.94        |
# | time/                   |             |
# |    fps                  | 508         |
# |    iterations           | 144         |
# |    time_elapsed         | 579         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.012171336 |
# |    clip_fraction        | 0.0842      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.397      |
# |    explained_variance   | 0.576       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 403         |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.021      |
# |    value_loss           | 1.38e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 242          |
# |    success_rate         | 0.96         |
# | time/                   |              |
# |    fps                  | 509          |
# |    iterations           | 145          |
# |    time_elapsed         | 583          |
# |    total_timesteps      | 296960       |
# | train/                  |              |
# |    approx_kl            | 0.0045215664 |
# |    clip_fraction        | 0.0306       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.23        |
# |    explained_variance   | 0.499        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 413          |
# |    n_updates            | 1440         |
# |    policy_gradient_loss | -0.0164      |
# |    value_loss           | 1.45e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 238          |
# |    success_rate         | 0.94         |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 146          |
# |    time_elapsed         | 587          |
# |    total_timesteps      | 299008       |
# | train/                  |              |
# |    approx_kl            | 0.0026933006 |
# |    clip_fraction        | 0.0292       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.333       |
# |    explained_variance   | 0.281        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 387          |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | -0.0185      |
# |    value_loss           | 1.05e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 244          |
# |    success_rate         | 0.97         |
# | time/                   |              |
# |    fps                  | 508          |
# |    iterations           | 147          |
# |    time_elapsed         | 591          |
# |    total_timesteps      | 301056       |
# | train/                  |              |
# |    approx_kl            | 0.0028038695 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.279       |
# |    explained_variance   | 0.771        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 399          |
# |    n_updates            | 1460         |
# |    policy_gradient_loss | -0.0216      |
# |    value_loss           | 999          |
# ------------------------------------------

# %%
state, _ = env.reset()
cumreward = 0
for i in range(MAX_STEPS):
  action,_ = model.predict(state)
  state, reward, terminated, truncated, info = env.step(action)
  cumreward +=reward
  print(PROCESSOR_ACTIONS[action], info, reward)
  if terminated or truncated:
    print(terminated)
    print(truncated)
    print(f"Episode finished after {i+1} timestamps")
    break
print(f"total reward {cumreward}")
# Out:
# (<Instruction.MOV: 0>, <Operand.RDX: 2>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=0 cmp_res=0', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=0 cmp_res=0', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=0 cmp_res=0', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=0 cmp_res=0', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=0 cmp_res=0', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=0 cmp_res=0', 'is_success': False} 2
# (<Instruction.CMP: 1>, <Operand.RSI: 1>, <Operand.RDX: 2>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=0 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=0 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=0 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=0 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=0 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=0 cmp_res=False', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=0 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=0 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=0 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=0 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=0 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=0 cmp_res=False', 'is_success': False} 2
# (<Instruction.MOV: 0>, <Operand.RDX: 2>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=2 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': False} 0
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 12
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=3 rcx=3 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=2 rcx=2 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=3 rcx=3 cmp_res=False', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=1 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=2 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=1 cmp_res=False', 'is_success': True} 10
# False
# True
# Episode finished after 30 timestamps
# total reward 256
