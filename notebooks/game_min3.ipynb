# %% [markdown]
# Using a test Model

# %%
from stable_baselines3 import PPO
import gymnasium as gym
import assembly_game
from assembly_game.processor import PROCESSOR_ACTIONS

# %%
MAX_STEPS = 30
env = gym.make("MinGame", max_episode_steps=MAX_STEPS, size = 3)

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=300000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 25.5     |
# |    ep_rew_mean     | 1        |
# | time/              |          |
# |    fps             | 3034     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.1        |
# |    ep_rew_mean          | 1.09        |
# | time/                   |             |
# |    fps                  | 2046        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011996741 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | 0.0654      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.176       |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0403     |
# |    value_loss           | 0.405       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.4        |
# |    ep_rew_mean          | 1.25        |
# | time/                   |             |
# |    fps                  | 1906        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.014027091 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.29        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0618      |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.051      |
# |    value_loss           | 0.333       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.1        |
# |    ep_rew_mean          | 1.51        |
# | time/                   |             |
# |    fps                  | 1831        |
# |    iterations           | 4           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014341785 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.426       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0494      |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0513     |
# |    value_loss           | 0.305       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.7         |
# |    ep_rew_mean          | 1.63         |
# | time/                   |              |
# |    fps                  | 1780         |
# |    iterations           | 5            |
# |    time_elapsed         | 5            |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0139802955 |
# |    clip_fraction        | 0.173        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.26        |
# |    explained_variance   | 0.61         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0837       |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.0469      |
# |    value_loss           | 0.229        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.1        |
# |    ep_rew_mean          | 1.66        |
# | time/                   |             |
# |    fps                  | 1774        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013715401 |
# |    clip_fraction        | 0.166       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.575       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0192      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0476     |
# |    value_loss           | 0.228       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28          |
# |    ep_rew_mean          | 1.76        |
# | time/                   |             |
# |    fps                  | 1744        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.013962913 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.22       |
# |    explained_variance   | 0.486       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.19        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 0.365       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.1        |
# |    ep_rew_mean          | 1.93        |
# | time/                   |             |
# |    fps                  | 1714        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.014160701 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.2        |
# |    explained_variance   | 0.609       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0372      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0419     |
# |    value_loss           | 0.273       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29          |
# |    ep_rew_mean          | 1.78        |
# | time/                   |             |
# |    fps                  | 1698        |
# |    iterations           | 9           |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015186969 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.19       |
# |    explained_variance   | 0.62        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0265      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 0.231       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.6        |
# |    ep_rew_mean          | 1.76        |
# | time/                   |             |
# |    fps                  | 1695        |
# |    iterations           | 10          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015084205 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.17       |
# |    explained_variance   | 0.652       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0363      |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0448     |
# |    value_loss           | 0.199       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29          |
# |    ep_rew_mean          | 1.95        |
# | time/                   |             |
# |    fps                  | 1689        |
# |    iterations           | 11          |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014417864 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.15       |
# |    explained_variance   | 0.721       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0151     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 0.127       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 1.93        |
# | time/                   |             |
# |    fps                  | 1688        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.013888421 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.625       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00363     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 0.201       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.8        |
# |    ep_rew_mean          | 1.93        |
# | time/                   |             |
# |    fps                  | 1688        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.015827518 |
# |    clip_fraction        | 0.186       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.701       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00323     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0487     |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.1        |
# |    ep_rew_mean          | 1.99        |
# | time/                   |             |
# |    fps                  | 1687        |
# |    iterations           | 14          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014416456 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.669       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00536     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0428     |
# |    value_loss           | 0.17        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.4        |
# |    ep_rew_mean          | 1.96        |
# | time/                   |             |
# |    fps                  | 1684        |
# |    iterations           | 15          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014300841 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.08       |
# |    explained_variance   | 0.661       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0146     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0452     |
# |    value_loss           | 0.142       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.2        |
# |    ep_rew_mean          | 2.1         |
# | time/                   |             |
# |    fps                  | 1679        |
# |    iterations           | 16          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015157413 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.06       |
# |    explained_variance   | 0.705       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0102     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0478     |
# |    value_loss           | 0.114       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.9        |
# |    ep_rew_mean          | 2.09        |
# | time/                   |             |
# |    fps                  | 1678        |
# |    iterations           | 17          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.015323135 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.732       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0112     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 0.107       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.6        |
# |    ep_rew_mean          | 2.27        |
# | time/                   |             |
# |    fps                  | 1672        |
# |    iterations           | 18          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.015521103 |
# |    clip_fraction        | 0.182       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.769       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0256     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0464     |
# |    value_loss           | 0.0766      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.4        |
# |    ep_rew_mean          | 2.33        |
# | time/                   |             |
# |    fps                  | 1670        |
# |    iterations           | 19          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.016242884 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.831       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0535     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0476     |
# |    value_loss           | 0.0531      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.5        |
# |    ep_rew_mean          | 2.73        |
# | time/                   |             |
# |    fps                  | 1670        |
# |    iterations           | 20          |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.009474209 |
# |    clip_fraction        | 0.0888      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.0385      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.362       |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0224     |
# |    value_loss           | 1.16        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 2.03        |
# | time/                   |             |
# |    fps                  | 1667        |
# |    iterations           | 21          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005257911 |
# |    clip_fraction        | 0.0195      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | -0.0481     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.166       |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 15.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.5        |
# |    ep_rew_mean          | 2.08        |
# | time/                   |             |
# |    fps                  | 1666        |
# |    iterations           | 22          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.012733404 |
# |    clip_fraction        | 0.149       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.631       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0123      |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0387     |
# |    value_loss           | 0.319       |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.7       |
# |    ep_rew_mean          | 3.43       |
# | time/                   |            |
# |    fps                  | 1667       |
# |    iterations           | 23         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 47104      |
# | train/                  |            |
# |    approx_kl            | 0.01592213 |
# |    clip_fraction        | 0.213      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.88      |
# |    explained_variance   | 0.527      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0719     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0444    |
# |    value_loss           | 0.279      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.4        |
# |    ep_rew_mean          | 2.31        |
# | time/                   |             |
# |    fps                  | 1666        |
# |    iterations           | 24          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.006499677 |
# |    clip_fraction        | 0.0403      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.86       |
# |    explained_variance   | 0.0371      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.2        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0141     |
# |    value_loss           | 43.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.8        |
# |    ep_rew_mean          | 2.84        |
# | time/                   |             |
# |    fps                  | 1669        |
# |    iterations           | 25          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.012201374 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.305       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.468       |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0373     |
# |    value_loss           | 1           |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 2.93        |
# | time/                   |             |
# |    fps                  | 1671        |
# |    iterations           | 26          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.010870753 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.161       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.06        |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0221     |
# |    value_loss           | 6.52        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.6        |
# |    ep_rew_mean          | 2.69        |
# | time/                   |             |
# |    fps                  | 1674        |
# |    iterations           | 27          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.013741858 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.572       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.131       |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0389     |
# |    value_loss           | 0.687       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.3        |
# |    ep_rew_mean          | 2.76        |
# | time/                   |             |
# |    fps                  | 1676        |
# |    iterations           | 28          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.013723487 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.501       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.137       |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0369     |
# |    value_loss           | 1.41        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 3.09        |
# | time/                   |             |
# |    fps                  | 1675        |
# |    iterations           | 29          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.014277602 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.463       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.496       |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0409     |
# |    value_loss           | 1.15        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.8        |
# |    ep_rew_mean          | 4.6         |
# | time/                   |             |
# |    fps                  | 1672        |
# |    iterations           | 30          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.013357423 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.411       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.259       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0313     |
# |    value_loss           | 2.59        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.6        |
# |    ep_rew_mean          | 10.1        |
# | time/                   |             |
# |    fps                  | 1672        |
# |    iterations           | 31          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.006861982 |
# |    clip_fraction        | 0.0608      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.037       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 214         |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0167     |
# |    value_loss           | 74.9        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.8         |
# |    ep_rew_mean          | 7.65         |
# | time/                   |              |
# |    fps                  | 1673         |
# |    iterations           | 32           |
# |    time_elapsed         | 39           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0048151026 |
# |    clip_fraction        | 0.0186       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.57        |
# |    explained_variance   | 0.0765       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.4         |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.00998     |
# |    value_loss           | 173          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 5.79        |
# | time/                   |             |
# |    fps                  | 1672        |
# |    iterations           | 33          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.011246591 |
# |    clip_fraction        | 0.127       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.5        |
# |    explained_variance   | 0.49        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.7         |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0291     |
# |    value_loss           | 6.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.8        |
# |    ep_rew_mean          | 6.41        |
# | time/                   |             |
# |    fps                  | 1671        |
# |    iterations           | 34          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.005554746 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.144       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 63.2        |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 93.9        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 6.12        |
# | time/                   |             |
# |    fps                  | 1670        |
# |    iterations           | 35          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008416735 |
# |    clip_fraction        | 0.0562      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.325       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 26.5        |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0148     |
# |    value_loss           | 56.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 7.85        |
# | time/                   |             |
# |    fps                  | 1669        |
# |    iterations           | 36          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008010289 |
# |    clip_fraction        | 0.0614      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.37       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 81.5        |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0158     |
# |    value_loss           | 105         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30         |
# |    ep_rew_mean          | 15         |
# | time/                   |            |
# |    fps                  | 1670       |
# |    iterations           | 37         |
# |    time_elapsed         | 45         |
# |    total_timesteps      | 75776      |
# | train/                  |            |
# |    approx_kl            | 0.00522489 |
# |    clip_fraction        | 0.0176     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.37      |
# |    explained_variance   | 0.24       |
# |    learning_rate        | 0.0003     |
# |    loss                 | 51.8       |
# |    n_updates            | 360        |
# |    policy_gradient_loss | -0.009     |
# |    value_loss           | 126        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30         |
# |    ep_rew_mean          | 19         |
# | time/                   |            |
# |    fps                  | 1668       |
# |    iterations           | 38         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 77824      |
# | train/                  |            |
# |    approx_kl            | 0.00521668 |
# |    clip_fraction        | 0.0225     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.35      |
# |    explained_variance   | 0.289      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 142        |
# |    n_updates            | 370        |
# |    policy_gradient_loss | -0.0116    |
# |    value_loss           | 341        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 11.7        |
# | time/                   |             |
# |    fps                  | 1667        |
# |    iterations           | 39          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.004160748 |
# |    clip_fraction        | 0.0127      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.3        |
# |    explained_variance   | 0.304       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 67.4        |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00822    |
# |    value_loss           | 327         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 9.61         |
# | time/                   |              |
# |    fps                  | 1666         |
# |    iterations           | 40           |
# |    time_elapsed         | 49           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0059451293 |
# |    clip_fraction        | 0.0244       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.22        |
# |    explained_variance   | 0.452        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 85           |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.012       |
# |    value_loss           | 157          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 13           |
# | time/                   |              |
# |    fps                  | 1665         |
# |    iterations           | 41           |
# |    time_elapsed         | 50           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0079167485 |
# |    clip_fraction        | 0.0381       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.15        |
# |    explained_variance   | 0.477        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 156          |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.0145      |
# |    value_loss           | 218          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 15.2        |
# | time/                   |             |
# |    fps                  | 1664        |
# |    iterations           | 42          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.009332782 |
# |    clip_fraction        | 0.0576      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.1        |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 220         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 292         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 18.1         |
# | time/                   |              |
# |    fps                  | 1663         |
# |    iterations           | 43           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0058456757 |
# |    clip_fraction        | 0.0289       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.04        |
# |    explained_variance   | 0.465        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 131          |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0119      |
# |    value_loss           | 368          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 18.1        |
# | time/                   |             |
# |    fps                  | 1662        |
# |    iterations           | 44          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.006190172 |
# |    clip_fraction        | 0.018       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.448       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 253         |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0104     |
# |    value_loss           | 523         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 13.9        |
# | time/                   |             |
# |    fps                  | 1661        |
# |    iterations           | 45          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005832982 |
# |    clip_fraction        | 0.00771     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.97       |
# |    explained_variance   | 0.449       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 140         |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00994    |
# |    value_loss           | 467         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.8         |
# |    ep_rew_mean          | 20.4         |
# | time/                   |              |
# |    fps                  | 1662         |
# |    iterations           | 46           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0060326047 |
# |    clip_fraction        | 0.0125       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.9         |
# |    explained_variance   | 0.507        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 225          |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00899     |
# |    value_loss           | 308          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.8         |
# |    ep_rew_mean          | 29.3         |
# | time/                   |              |
# |    fps                  | 1662         |
# |    iterations           | 47           |
# |    time_elapsed         | 57           |
# |    total_timesteps      | 96256        |
# | train/                  |              |
# |    approx_kl            | 0.0077231405 |
# |    clip_fraction        | 0.0241       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.82        |
# |    explained_variance   | 0.465        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 394          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.0104      |
# |    value_loss           | 656          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 26.2        |
# | time/                   |             |
# |    fps                  | 1661        |
# |    iterations           | 48          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.003522972 |
# |    clip_fraction        | 0.00767     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.443       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 263         |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00903    |
# |    value_loss           | 668         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 27.8         |
# | time/                   |              |
# |    fps                  | 1660         |
# |    iterations           | 49           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 100352       |
# | train/                  |              |
# |    approx_kl            | 0.0064613717 |
# |    clip_fraction        | 0.0155       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.75        |
# |    explained_variance   | 0.445        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 206          |
# |    n_updates            | 480          |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 704          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 39.5        |
# | time/                   |             |
# |    fps                  | 1658        |
# |    iterations           | 50          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.007949375 |
# |    clip_fraction        | 0.0587      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 0.464       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 422         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0161     |
# |    value_loss           | 745         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 34.9         |
# | time/                   |              |
# |    fps                  | 1658         |
# |    iterations           | 51           |
# |    time_elapsed         | 62           |
# |    total_timesteps      | 104448       |
# | train/                  |              |
# |    approx_kl            | 0.0072586187 |
# |    clip_fraction        | 0.0388       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.78        |
# |    explained_variance   | 0.498        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 624          |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.0129      |
# |    value_loss           | 1.16e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30         |
# |    ep_rew_mean          | 44.3       |
# | time/                   |            |
# |    fps                  | 1657       |
# |    iterations           | 52         |
# |    time_elapsed         | 64         |
# |    total_timesteps      | 106496     |
# | train/                  |            |
# |    approx_kl            | 0.00810653 |
# |    clip_fraction        | 0.0433     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.69      |
# |    explained_variance   | 0.612      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 354        |
# |    n_updates            | 510        |
# |    policy_gradient_loss | -0.0122    |
# |    value_loss           | 638        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 50.3        |
# | time/                   |             |
# |    fps                  | 1656        |
# |    iterations           | 53          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 108544      |
# | train/                  |             |
# |    approx_kl            | 0.006641157 |
# |    clip_fraction        | 0.0329      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.468       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 601         |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.012      |
# |    value_loss           | 1.26e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 56.5         |
# | time/                   |              |
# |    fps                  | 1656         |
# |    iterations           | 54           |
# |    time_elapsed         | 66           |
# |    total_timesteps      | 110592       |
# | train/                  |              |
# |    approx_kl            | 0.0062646316 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.68        |
# |    explained_variance   | 0.484        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 503          |
# |    n_updates            | 530          |
# |    policy_gradient_loss | -0.0101      |
# |    value_loss           | 1.22e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 55.5         |
# | time/                   |              |
# |    fps                  | 1656         |
# |    iterations           | 55           |
# |    time_elapsed         | 68           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0089131985 |
# |    clip_fraction        | 0.0584       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.71        |
# |    explained_variance   | 0.505        |
# |    learning_rate        | 0.0003       |
# ...
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 1625         |
# |    iterations           | 130          |
# |    time_elapsed         | 163          |
# |    total_timesteps      | 266240       |
# | train/                  |              |
# |    approx_kl            | 0.0050500063 |
# |    clip_fraction        | 0.0489       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.832       |
# |    explained_variance   | 0.000349     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 492          |
# |    n_updates            | 1290         |
# |    policy_gradient_loss | -0.00778     |
# |    value_loss           | 1.12e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 240          |
# | time/                   |              |
# |    fps                  | 1625         |
# |    iterations           | 131          |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 268288       |
# | train/                  |              |
# |    approx_kl            | 0.0070867334 |
# |    clip_fraction        | 0.07         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.96        |
# |    explained_variance   | 0.254        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 505          |
# |    n_updates            | 1300         |
# |    policy_gradient_loss | -0.0144      |
# |    value_loss           | 1.21e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 235         |
# | time/                   |             |
# |    fps                  | 1625        |
# |    iterations           | 132         |
# |    time_elapsed         | 166         |
# |    total_timesteps      | 270336      |
# | train/                  |             |
# |    approx_kl            | 0.007424926 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.728      |
# |    explained_variance   | 0.0845      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 612         |
# |    n_updates            | 1310        |
# |    policy_gradient_loss | -0.0126     |
# |    value_loss           | 1.49e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 237         |
# | time/                   |             |
# |    fps                  | 1625        |
# |    iterations           | 133         |
# |    time_elapsed         | 167         |
# |    total_timesteps      | 272384      |
# | train/                  |             |
# |    approx_kl            | 0.008341609 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.728      |
# |    explained_variance   | 0.617       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 428         |
# |    n_updates            | 1320        |
# |    policy_gradient_loss | -0.0166     |
# |    value_loss           | 1.37e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 242          |
# | time/                   |              |
# |    fps                  | 1626         |
# |    iterations           | 134          |
# |    time_elapsed         | 168          |
# |    total_timesteps      | 274432       |
# | train/                  |              |
# |    approx_kl            | 0.0043775747 |
# |    clip_fraction        | 0.0447       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.707       |
# |    explained_variance   | 0.696        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 437          |
# |    n_updates            | 1330         |
# |    policy_gradient_loss | -0.00859     |
# |    value_loss           | 1.51e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 242         |
# | time/                   |             |
# |    fps                  | 1626        |
# |    iterations           | 135         |
# |    time_elapsed         | 170         |
# |    total_timesteps      | 276480      |
# | train/                  |             |
# |    approx_kl            | 0.006412415 |
# |    clip_fraction        | 0.0712      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.912      |
# |    explained_variance   | -0.0207     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 365         |
# |    n_updates            | 1340        |
# |    policy_gradient_loss | -0.0118     |
# |    value_loss           | 941         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 236          |
# | time/                   |              |
# |    fps                  | 1626         |
# |    iterations           | 136          |
# |    time_elapsed         | 171          |
# |    total_timesteps      | 278528       |
# | train/                  |              |
# |    approx_kl            | 0.0061105723 |
# |    clip_fraction        | 0.0822       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.777       |
# |    explained_variance   | 0.318        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 976          |
# |    n_updates            | 1350         |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 1.4e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 1626         |
# |    iterations           | 137          |
# |    time_elapsed         | 172          |
# |    total_timesteps      | 280576       |
# | train/                  |              |
# |    approx_kl            | 0.0075129825 |
# |    clip_fraction        | 0.0884       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.789       |
# |    explained_variance   | 0.302        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 584          |
# |    n_updates            | 1360         |
# |    policy_gradient_loss | -0.0163      |
# |    value_loss           | 1.56e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 1626         |
# |    iterations           | 138          |
# |    time_elapsed         | 173          |
# |    total_timesteps      | 282624       |
# | train/                  |              |
# |    approx_kl            | 0.0033461647 |
# |    clip_fraction        | 0.0552       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.652       |
# |    explained_variance   | 0.00251      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 371          |
# |    n_updates            | 1370         |
# |    policy_gradient_loss | -0.00803     |
# |    value_loss           | 846          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 234         |
# | time/                   |             |
# |    fps                  | 1627        |
# |    iterations           | 139         |
# |    time_elapsed         | 174         |
# |    total_timesteps      | 284672      |
# | train/                  |             |
# |    approx_kl            | 0.005665031 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.689      |
# |    explained_variance   | 0.00409     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 321         |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.0106     |
# |    value_loss           | 852         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 233         |
# | time/                   |             |
# |    fps                  | 1627        |
# |    iterations           | 140         |
# |    time_elapsed         | 176         |
# |    total_timesteps      | 286720      |
# | train/                  |             |
# |    approx_kl            | 0.010086542 |
# |    clip_fraction        | 0.0984      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.725      |
# |    explained_variance   | 0.407       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 393         |
# |    n_updates            | 1390        |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 1.18e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 238          |
# | time/                   |              |
# |    fps                  | 1627         |
# |    iterations           | 141          |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 288768       |
# | train/                  |              |
# |    approx_kl            | 0.0049167275 |
# |    clip_fraction        | 0.0504       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.587       |
# |    explained_variance   | 0.771        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 317          |
# |    n_updates            | 1400         |
# |    policy_gradient_loss | -0.0118      |
# |    value_loss           | 852          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 234          |
# | time/                   |              |
# |    fps                  | 1626         |
# |    iterations           | 142          |
# |    time_elapsed         | 178          |
# |    total_timesteps      | 290816       |
# | train/                  |              |
# |    approx_kl            | 0.0058230744 |
# |    clip_fraction        | 0.0707       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.528       |
# |    explained_variance   | 0.874        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 368          |
# |    n_updates            | 1410         |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 867          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 241          |
# | time/                   |              |
# |    fps                  | 1626         |
# |    iterations           | 143          |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 292864       |
# | train/                  |              |
# |    approx_kl            | 0.0058521237 |
# |    clip_fraction        | 0.07         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.538       |
# |    explained_variance   | 0.368        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 334          |
# |    n_updates            | 1420         |
# |    policy_gradient_loss | -0.018       |
# |    value_loss           | 1.27e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 237          |
# | time/                   |              |
# |    fps                  | 1626         |
# |    iterations           | 144          |
# |    time_elapsed         | 181          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0071686874 |
# |    clip_fraction        | 0.0688       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.393       |
# |    explained_variance   | 0.159        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 261          |
# |    n_updates            | 1430         |
# |    policy_gradient_loss | -0.00851     |
# |    value_loss           | 662          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 238         |
# | time/                   |             |
# |    fps                  | 1626        |
# |    iterations           | 145         |
# |    time_elapsed         | 182         |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 0.006075185 |
# |    clip_fraction        | 0.0628      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.475      |
# |    explained_variance   | 0.614       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 856         |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | -0.0115     |
# |    value_loss           | 1.19e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30           |
# |    ep_rew_mean          | 231          |
# | time/                   |              |
# |    fps                  | 1625         |
# |    iterations           | 146          |
# |    time_elapsed         | 183          |
# |    total_timesteps      | 299008       |
# | train/                  |              |
# |    approx_kl            | 0.0058340672 |
# |    clip_fraction        | 0.0621       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.391       |
# |    explained_variance   | 0.155        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 289          |
# |    n_updates            | 1450         |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 665          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 230         |
# | time/                   |             |
# |    fps                  | 1626        |
# |    iterations           | 147         |
# |    time_elapsed         | 185         |
# |    total_timesteps      | 301056      |
# | train/                  |             |
# |    approx_kl            | 0.005488732 |
# |    clip_fraction        | 0.0547      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.454      |
# |    explained_variance   | 0.469       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 453         |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | -0.0122     |
# |    value_loss           | 835         |
# -----------------------------------------

# %%
state, _ = env.reset()
cumreward = 0
for i in range(MAX_STEPS):
  action,_ = model.predict(state)
  state, reward, terminated, truncated, info = env.step(action)
  cumreward +=reward
  print(PROCESSOR_ACTIONS[action], info, reward)
  if terminated or truncated:
    print(terminated)
    print(truncated)
    print(f"Episode finished after {i+1} timestamps")
    break
print(f"total reward {cumreward}")
# Out:
# (<Instruction.MOV: 0>, <Operand.RSI: 1>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=2 rax=0 rdx=3 rcx=2 cmp_res=0', 'example_1': 'rdi=1 rsi=3 rax=0 rdx=2 rcx=3 cmp_res=0', 'example_2': 'rdi=2 rsi=1 rax=0 rdx=3 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=3 rax=0 rdx=1 rcx=3 cmp_res=0', 'example_4': 'rdi=3 rsi=1 rax=0 rdx=2 rcx=1 cmp_res=0', 'example_5': 'rdi=3 rsi=2 rax=0 rdx=1 rcx=2 cmp_res=0'} 0
# (<Instruction.MOV: 0>, <Operand.RDX: 2>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=2 cmp_res=0', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=3 cmp_res=0', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=0', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=0', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=0'} 2
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RDX: 2>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=3 rcx=2 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=2 rcx=3 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=3 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 0
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RDX: 2>) {'example_0': 'rdi=1 rsi=2 rax=3 rdx=1 rcx=2 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=2 rdx=1 rcx=3 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=3 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 0
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=True', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=True', 'example_2': 'rdi=2 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=False', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 2
# (<Instruction.CMP: 1>, <Operand.RCX: 3>, <Operand.RDX: 2>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=2 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 0
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 12
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False', 'example_1': 'rdi=1 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_2': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_3': 'rdi=2 rsi=3 rax=1 rdx=1 rcx=3 cmp_res=False', 'example_4': 'rdi=3 rsi=1 rax=1 rdx=2 rcx=1 cmp_res=True', 'example_5': 'rdi=3 rsi=2 rax=1 rdx=1 rcx=2 cmp_res=False'} 10
# False
# True
# Episode finished after 30 timestamps
# total reward 246
