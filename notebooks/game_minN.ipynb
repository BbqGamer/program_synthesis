# %% [markdown]
# # Now let's see how to add timelimit to the environment

# %% [markdown]
# Using a test Model

# %%
import gymnasium as gym
import assembly_game
from assembly_game.processor import PROCESSOR_ACTIONS
from stable_baselines3 import PPO

# %%
MAX_STEPS = 30
env = gym.make("MinNGame", max_episode_steps=MAX_STEPS, n=3)

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=200_000)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /home/konstanty/STUDIA/masters_1_sem/program_synthesis/.venv/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 26.1     |
# |    ep_rew_mean     | 0.987    |
# |    success_rate    | 0        |
# | time/              |          |
# |    fps             | 1153     |
# |    iterations      | 1        |
# |    time_elapsed    | 1        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.1        |
# |    ep_rew_mean          | 1.09        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 894         |
# |    iterations           | 2           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.011195509 |
# |    clip_fraction        | 0.114       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | -0.0464     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0232      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 0.267       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.2        |
# |    ep_rew_mean          | 1.26        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 855         |
# |    iterations           | 3           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.013275735 |
# |    clip_fraction        | 0.14        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.31       |
# |    explained_variance   | 0.398       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00994    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0531     |
# |    value_loss           | 0.181       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 1.4         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 837         |
# |    iterations           | 4           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.014557353 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.29       |
# |    explained_variance   | 0.679       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0306     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0571     |
# |    value_loss           | 0.133       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.5        |
# |    ep_rew_mean          | 1.57        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 832         |
# |    iterations           | 5           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013844965 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.27       |
# |    explained_variance   | 0.758       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0447     |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0563     |
# |    value_loss           | 0.0978      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.4        |
# |    ep_rew_mean          | 1.8         |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 841         |
# |    iterations           | 6           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.014181565 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.24       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0181     |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0548     |
# |    value_loss           | 0.11        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23         |
# |    ep_rew_mean          | 1.96       |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 851        |
# |    iterations           | 7          |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.01556482 |
# |    clip_fraction        | 0.181      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.21      |
# |    explained_variance   | 0.823      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0663    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0558    |
# |    value_loss           | 0.0773     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 19.5       |
# |    ep_rew_mean          | 1.94       |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 854        |
# |    iterations           | 8          |
# |    time_elapsed         | 19         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.01565073 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -4.18      |
# |    explained_variance   | 0.871      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0616    |
# |    n_updates            | 70         |
# |    policy_gradient_loss | -0.0555    |
# |    value_loss           | 0.0584     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.8        |
# |    ep_rew_mean          | 1.99        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 9           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.015921645 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.14       |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.074      |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0536     |
# |    value_loss           | 0.0451      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.1        |
# |    ep_rew_mean          | 1.99        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 858         |
# |    iterations           | 10          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.016184315 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0637     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0513     |
# |    value_loss           | 0.0175      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.8        |
# |    ep_rew_mean          | 2.01        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 11          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.014235602 |
# |    clip_fraction        | 0.168       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0175     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.045      |
# |    value_loss           | 0.0275      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.5        |
# |    ep_rew_mean          | 1.96        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 862         |
# |    iterations           | 12          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.014635891 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.07       |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0549     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0471     |
# |    value_loss           | 0.023       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.3        |
# |    ep_rew_mean          | 2.01        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 13          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.014953164 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.03       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0668     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0465     |
# |    value_loss           | 0.0183      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.9        |
# |    ep_rew_mean          | 1.98        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 864         |
# |    iterations           | 14          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.014874099 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0626     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0447     |
# |    value_loss           | 0.0231      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.7        |
# |    ep_rew_mean          | 2           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 865         |
# |    iterations           | 15          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014262121 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0358     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0436     |
# |    value_loss           | 0.0293      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 21.8        |
# |    ep_rew_mean          | 1.99        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 865         |
# |    iterations           | 16          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.013589981 |
# |    clip_fraction        | 0.15        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.02       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0435     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0409     |
# |    value_loss           | 0.0157      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.7        |
# |    ep_rew_mean          | 1.98        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 17          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.014612189 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0608     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0422     |
# |    value_loss           | 0.0149      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20.9        |
# |    ep_rew_mean          | 2.01        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 18          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.013291801 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0598     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0427     |
# |    value_loss           | 0.0187      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.2        |
# |    ep_rew_mean          | 2           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 19          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.014853762 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.896       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0453     |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.046      |
# |    value_loss           | 0.0179      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.3        |
# |    ep_rew_mean          | 2.05        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 20          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.014311941 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4          |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0505     |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0447     |
# |    value_loss           | 0.017       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24          |
# |    ep_rew_mean          | 1.99        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 21          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.015747618 |
# |    clip_fraction        | 0.169       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.97       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0705     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0461     |
# |    value_loss           | 0.0173      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.2        |
# |    ep_rew_mean          | 2           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 22          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.015899342 |
# |    clip_fraction        | 0.187       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.98       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0936     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0486     |
# |    value_loss           | 0.00762     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.6        |
# |    ep_rew_mean          | 2.02        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 23          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.014254132 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0763     |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 0.00863     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 24.1         |
# |    ep_rew_mean          | 2.01         |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 865          |
# |    iterations           | 24           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0135029815 |
# |    clip_fraction        | 0.134        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.95        |
# |    explained_variance   | 0.9          |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0475      |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0386      |
# |    value_loss           | 0.0154       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25          |
# |    ep_rew_mean          | 2.03        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 25          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.014092185 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.92       |
# |    explained_variance   | 0.835       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0114     |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0424     |
# |    value_loss           | 0.0301      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.9        |
# |    ep_rew_mean          | 2.02        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 868         |
# |    iterations           | 26          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.015842546 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.9        |
# |    explained_variance   | 0.849       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0612     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0494     |
# |    value_loss           | 0.0185      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25.2       |
# |    ep_rew_mean          | 2.02       |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 867        |
# |    iterations           | 27         |
# |    time_elapsed         | 63         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01642884 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.87      |
# |    explained_variance   | 0.755      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0619    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0499    |
# |    value_loss           | 0.0337     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.6       |
# |    ep_rew_mean          | 1.99       |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 867        |
# |    iterations           | 28         |
# |    time_elapsed         | 66         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.01725242 |
# |    clip_fraction        | 0.183      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.85      |
# |    explained_variance   | 0.829      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.044     |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0496    |
# |    value_loss           | 0.0251     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.3        |
# |    ep_rew_mean          | 2.03        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 29          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.016099565 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0734     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 0.0166      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.7        |
# |    ep_rew_mean          | 2.01        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 30          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.016297093 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.81       |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0444     |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0483     |
# |    value_loss           | 0.0186      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.8        |
# |    ep_rew_mean          | 2.04        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 31          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.014028861 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.75       |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.035      |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.0418     |
# |    value_loss           | 0.034       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.8        |
# |    ep_rew_mean          | 2.05        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 867         |
# |    iterations           | 32          |
# |    time_elapsed         | 75          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.017392404 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0593     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0505     |
# |    value_loss           | 0.0189      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29          |
# |    ep_rew_mean          | 2.02        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 868         |
# |    iterations           | 33          |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.014617787 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0717     |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 0.0093      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.5        |
# |    ep_rew_mean          | 2.01        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 34          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.015196865 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0524     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0415     |
# |    value_loss           | 0.0168      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.6        |
# |    ep_rew_mean          | 2.01        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 870         |
# |    iterations           | 35          |
# |    time_elapsed         | 82          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.015433418 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.876       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0724     |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0455     |
# |    value_loss           | 0.0131      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.1       |
# |    ep_rew_mean          | 2          |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 870        |
# |    iterations           | 36         |
# |    time_elapsed         | 84         |
# |    total_timesteps      | 73728      |
# | train/                  |            |
# |    approx_kl            | 0.01623278 |
# |    clip_fraction        | 0.18       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.62      |
# |    explained_variance   | 0.89       |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0845    |
# |    n_updates            | 350        |
# |    policy_gradient_loss | -0.0459    |
# |    value_loss           | 0.0122     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.6        |
# |    ep_rew_mean          | 2.02        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 870         |
# |    iterations           | 37          |
# |    time_elapsed         | 87          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.016515192 |
# |    clip_fraction        | 0.201       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0492     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0454     |
# |    value_loss           | 0.01        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.2        |
# |    ep_rew_mean          | 2.04        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 38          |
# |    time_elapsed         | 89          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.015803022 |
# |    clip_fraction        | 0.173       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.53       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0537     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 0.00841     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.6        |
# |    ep_rew_mean          | 2.03        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 39          |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.015174794 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.866       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0564     |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.0433     |
# |    value_loss           | 0.0121      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.8        |
# |    ep_rew_mean          | 2.01        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 869         |
# |    iterations           | 40          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.014638761 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.875       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0639     |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0417     |
# |    value_loss           | 0.0136      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 2.02        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 868         |
# |    iterations           | 41          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.015921127 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0541     |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0424     |
# |    value_loss           | 0.00674     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 2.05        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 868         |
# |    iterations           | 42          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.014859662 |
# |    clip_fraction        | 0.178       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0732     |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0459     |
# |    value_loss           | 0.00811     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 29.4         |
# |    ep_rew_mean          | 2.05         |
# |    success_rate         | 0            |
# | time/                   |              |
# |    fps                  | 867          |
# |    iterations           | 43           |
# |    time_elapsed         | 101          |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0148819955 |
# |    clip_fraction        | 0.179        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.53        |
# |    explained_variance   | 0.847        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.044       |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.0402      |
# |    value_loss           | 0.0147       |
# ------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 28.6     |
# |    ep_rew_mean          | 2.05     |
# |    success_rate         | 0        |
# | time/                   |          |
# |    fps                  | 866      |
# |    iterations           | 44       |
# |    time_elapsed         | 103      |
# |    total_timesteps      | 90112    |
# | train/                  |          |
# |    approx_kl            | 0.015852 |
# |    clip_fraction        | 0.169    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -3.52    |
# |    explained_variance   | 0.803    |
# |    learning_rate        | 0.0003   |
# |    loss                 | -0.0562  |
# |    n_updates            | 430      |
# |    policy_gradient_loss | -0.0433  |
# |    value_loss           | 0.0214   |
# --------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 29.1       |
# |    ep_rew_mean          | 1.99       |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 866        |
# |    iterations           | 45         |
# |    time_elapsed         | 106        |
# |    total_timesteps      | 92160      |
# | train/                  |            |
# |    approx_kl            | 0.01520204 |
# |    clip_fraction        | 0.171      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.49      |
# |    explained_variance   | 0.829      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0648    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0411    |
# |    value_loss           | 0.0172     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 2.08        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 46          |
# |    time_elapsed         | 108         |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.014963762 |
# |    clip_fraction        | 0.18        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.48       |
# |    explained_variance   | 0.832       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0536     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0473     |
# |    value_loss           | 0.0163      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 2.09        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 47          |
# |    time_elapsed         | 111         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.014708548 |
# |    clip_fraction        | 0.17        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.729       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0503     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0465     |
# |    value_loss           | 0.0395      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 2.18        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 866         |
# |    iterations           | 48          |
# |    time_elapsed         | 113         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.016670942 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.47       |
# |    explained_variance   | 0.782       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0597     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0513     |
# |    value_loss           | 0.0286      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.8        |
# |    ep_rew_mean          | 2.22        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 865         |
# |    iterations           | 49          |
# |    time_elapsed         | 115         |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.017643176 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.41       |
# |    explained_variance   | 0.691       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0252     |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.0474     |
# |    value_loss           | 0.0598      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.5        |
# |    ep_rew_mean          | 2.21        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 865         |
# |    iterations           | 50          |
# |    time_elapsed         | 118         |
# |    total_timesteps      | 102400      |
# | train/                  |             |
# |    approx_kl            | 0.016578984 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.4        |
# |    explained_variance   | 0.764       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0637     |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0504     |
# |    value_loss           | 0.039       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.1        |
# |    ep_rew_mean          | 2.34        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 865         |
# |    iterations           | 51          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.015803713 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.31       |
# |    explained_variance   | 0.786       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0556     |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.0484     |
# |    value_loss           | 0.0404      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.5        |
# |    ep_rew_mean          | 2.44        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 865         |
# |    iterations           | 52          |
# |    time_elapsed         | 123         |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.014233921 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.27       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0408     |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0489     |
# ...
# |    entropy_loss         | -2.74      |
# |    explained_variance   | 0.993      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.046     |
# |    n_updates            | 800        |
# |    policy_gradient_loss | -0.027     |
# |    value_loss           | 0.00186    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.7        |
# |    ep_rew_mean          | 3           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 82          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 167936      |
# | train/                  |             |
# |    approx_kl            | 0.015304236 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0579     |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.0272     |
# |    value_loss           | 0.00167     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.8        |
# |    ep_rew_mean          | 3           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 83          |
# |    time_elapsed         | 198         |
# |    total_timesteps      | 169984      |
# | train/                  |             |
# |    approx_kl            | 0.015633173 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.75       |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00623     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.028      |
# |    value_loss           | 0.000453    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 3           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 84          |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 172032      |
# | train/                  |             |
# |    approx_kl            | 0.017316207 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.74       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0275     |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.0273     |
# |    value_loss           | 0.000174    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 2.99        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 85          |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 174080      |
# | train/                  |             |
# |    approx_kl            | 0.022796066 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.77       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0342     |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.0271     |
# |    value_loss           | 0.000117    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 3           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 86          |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 176128      |
# | train/                  |             |
# |    approx_kl            | 0.015904691 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.73       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0458     |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.0252     |
# |    value_loss           | 0.000284    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30         |
# |    ep_rew_mean          | 3          |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 854        |
# |    iterations           | 87         |
# |    time_elapsed         | 208        |
# |    total_timesteps      | 178176     |
# | train/                  |            |
# |    approx_kl            | 0.08063872 |
# |    clip_fraction        | 0.316      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.67      |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0822    |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.033     |
# |    value_loss           | 2.44e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 3           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 88          |
# |    time_elapsed         | 210         |
# |    total_timesteps      | 180224      |
# | train/                  |             |
# |    approx_kl            | 0.028263308 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.59       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0517     |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.0234     |
# |    value_loss           | 3.17e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 3           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 89          |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 182272      |
# | train/                  |             |
# |    approx_kl            | 0.011694526 |
# |    clip_fraction        | 0.163       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.69       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0392     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 3.97e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 3           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 90          |
# |    time_elapsed         | 215         |
# |    total_timesteps      | 184320      |
# | train/                  |             |
# |    approx_kl            | 0.014534094 |
# |    clip_fraction        | 0.165       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00494    |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.0237     |
# |    value_loss           | 1.61e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.8        |
# |    ep_rew_mean          | 3           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 854         |
# |    iterations           | 91          |
# |    time_elapsed         | 218         |
# |    total_timesteps      | 186368      |
# | train/                  |             |
# |    approx_kl            | 0.012498589 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.63       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0485     |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0227     |
# |    value_loss           | 2.09e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.8        |
# |    ep_rew_mean          | 3           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 92          |
# |    time_elapsed         | 220         |
# |    total_timesteps      | 188416      |
# | train/                  |             |
# |    approx_kl            | 0.015777776 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00276     |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.0251     |
# |    value_loss           | 4.48e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 3           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 93          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 190464      |
# | train/                  |             |
# |    approx_kl            | 0.039514646 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0301     |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.0211     |
# |    value_loss           | 1.1e-05     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | 3           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 94          |
# |    time_elapsed         | 225         |
# |    total_timesteps      | 192512      |
# | train/                  |             |
# |    approx_kl            | 0.012759486 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0377     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0228     |
# |    value_loss           | 1.98e-05    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 3           |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 95          |
# |    time_elapsed         | 227         |
# |    total_timesteps      | 194560      |
# | train/                  |             |
# |    approx_kl            | 0.010805305 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 1           |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0129     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.0208     |
# |    value_loss           | 8.61e-05    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 30         |
# |    ep_rew_mean          | 2.99       |
# |    success_rate         | 0          |
# | time/                   |            |
# |    fps                  | 853        |
# |    iterations           | 96         |
# |    time_elapsed         | 230        |
# |    total_timesteps      | 196608     |
# | train/                  |            |
# |    approx_kl            | 0.02101657 |
# |    clip_fraction        | 0.153      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.6       |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0464    |
# |    n_updates            | 950        |
# |    policy_gradient_loss | -0.0284    |
# |    value_loss           | 1.17e-05   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 2.98        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 97          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 198656      |
# | train/                  |             |
# |    approx_kl            | 0.017291754 |
# |    clip_fraction        | 0.174       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0428     |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.0288     |
# |    value_loss           | 0.000206    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30          |
# |    ep_rew_mean          | 2.98        |
# |    success_rate         | 0           |
# | time/                   |             |
# |    fps                  | 853         |
# |    iterations           | 98          |
# |    time_elapsed         | 235         |
# |    total_timesteps      | 200704      |
# | train/                  |             |
# |    approx_kl            | 0.020322438 |
# |    clip_fraction        | 0.146       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.039      |
# |    n_updates            | 970         |
# |    policy_gradient_loss | -0.0231     |
# |    value_loss           | 0.000125    |
# -----------------------------------------

# %%
state, _ = env.reset()
cumreward = 0
for i in range(MAX_STEPS):
  action,_ = model.predict(state)
  state, reward, terminated, truncated, info = env.step(action)
  cumreward +=reward
  print(PROCESSOR_ACTIONS[action], info, reward)
  if terminated or truncated:
    print(terminated)
    print(truncated)
    print(f"Episode finished after {i+1} timestamps")
    break
print(f"total reward {cumreward}")
# Out:
# (<Instruction.MOV: 0>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=2 rcx=0 cmp_res=0', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=1 rcx=0 cmp_res=0', 'example_2': 'rdi=1 rsi=0 rax=0 rdx=2 rcx=0 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=0 rcx=0 cmp_res=0', 'example_4': 'rdi=2 rsi=0 rax=0 rdx=1 rcx=0 cmp_res=0', 'example_5': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=0 cmp_res=0', 'is_success': False} 2
# (<Instruction.CMP: 1>, <Operand.RCX: 3>, <Operand.RAX: 4>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=2 rcx=0 cmp_res=1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=1 rcx=0 cmp_res=2', 'example_2': 'rdi=1 rsi=0 rax=0 rdx=2 rcx=0 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=0 rcx=0 cmp_res=2', 'example_4': 'rdi=2 rsi=0 rax=0 rdx=1 rcx=0 cmp_res=0', 'example_5': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=0 cmp_res=1', 'is_success': False} 0
# (<Instruction.MOV: 0>, <Operand.RDI: 0>, <Operand.RDX: 2>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=0 rcx=0 cmp_res=1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=0 rcx=0 cmp_res=2', 'example_2': 'rdi=1 rsi=0 rax=0 rdx=1 rcx=0 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=1 rcx=0 cmp_res=2', 'example_4': 'rdi=2 rsi=0 rax=0 rdx=2 rcx=0 cmp_res=0', 'example_5': 'rdi=2 rsi=1 rax=1 rdx=2 rcx=0 cmp_res=1', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RDX: 2>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=0 cmp_res=1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=0 cmp_res=2', 'example_2': 'rdi=1 rsi=0 rax=0 rdx=1 rcx=0 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=0 cmp_res=2', 'example_4': 'rdi=2 rsi=0 rax=0 rdx=2 rcx=0 cmp_res=0', 'example_5': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=0 cmp_res=1', 'is_success': False} 0
# (<Instruction.MOV: 0>, <Operand.RDX: 2>, <Operand.RAX: 4>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=0 cmp_res=1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=0 cmp_res=2', 'example_2': 'rdi=1 rsi=0 rax=1 rdx=1 rcx=0 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=0 cmp_res=2', 'example_4': 'rdi=2 rsi=0 rax=2 rdx=2 rcx=0 cmp_res=0', 'example_5': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=0 cmp_res=1', 'is_success': False} 1
# (<Instruction.MOV: 0>, <Operand.RDX: 2>, <Operand.RAX: 4>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=0 cmp_res=1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=0 cmp_res=2', 'example_2': 'rdi=1 rsi=0 rax=1 rdx=1 rcx=0 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=0 cmp_res=2', 'example_4': 'rdi=2 rsi=0 rax=2 rdx=2 rcx=0 cmp_res=0', 'example_5': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=0 cmp_res=1', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RCX: 3>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=0 cmp_res=1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=0 cmp_res=2', 'example_2': 'rdi=1 rsi=0 rax=1 rdx=1 rcx=0 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=0 cmp_res=2', 'example_4': 'rdi=2 rsi=0 rax=2 rdx=2 rcx=0 cmp_res=0', 'example_5': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=0 cmp_res=1', 'is_success': False} 0
# (<Instruction.MOV: 0>, <Operand.RAX: 4>, <Operand.RCX: 3>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=2', 'example_2': 'rdi=1 rsi=0 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=2', 'example_4': 'rdi=2 rsi=0 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=1', 'is_success': False} 0
# (<Instruction.MOV: 0>, <Operand.RDX: 2>, <Operand.RSI: 1>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=2', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=2', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=1', 'is_success': False} 0
# (<Instruction.CMP: 1>, <Operand.RCX: 3>, <Operand.RDI: 0>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=-1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-2', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-1', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=1', 'is_success': False} 0
# (<Instruction.MOV: 0>, <Operand.RDX: 2>, <Operand.RSI: 1>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=-1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-2', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-1', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=2 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=1', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RSI: 1>, <Operand.RDI: 0>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=-1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-2', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-1', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=1', 'is_success': False} 0
# (<Instruction.CMP: 1>, <Operand.RSI: 1>, <Operand.RDI: 0>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=-1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-2', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-1', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMP: 1>, <Operand.RDX: 2>, <Operand.RDI: 0>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=-1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-2', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-1', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RDX: 2>, <Operand.RDI: 0>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=-1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-2', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-1', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RDX: 2>, <Operand.RDI: 0>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=-1', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-2', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=-1', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMP: 1>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMP: 1>, <Operand.RSI: 1>, <Operand.RCX: 3>) {'example_0': 'rdi=0 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=0 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=1 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.MOV: 0>, <Operand.RCX: 3>, <Operand.RDI: 0>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMP: 1>, <Operand.RSI: 1>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RDX: 2>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RDI: 0>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RDX: 2>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.MOV: 0>, <Operand.RDX: 2>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RDX: 2>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RDX: 2>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMP: 1>, <Operand.RSI: 1>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMOVG: 2>, <Operand.RCX: 3>, <Operand.RDX: 2>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_2': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'example_3': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_4': 'rdi=2 rsi=2 rax=2 rdx=2 rcx=2 cmp_res=0', 'example_5': 'rdi=1 rsi=1 rax=1 rdx=1 rcx=1 cmp_res=0', 'is_success': False} 0
# False
# True
# Episode finished after 30 timestamps
# total reward 3
