# %% [markdown]
# # Now let's see how to add timelimit to the environment

# %% [markdown]
# After 4 steps the truncated is being set to True, indicating that the episode has ended due to the time limit.

# %% [markdown]
# Using a test Model

# %%
from stable_baselines3 import PPO
import gymnasium as gym
from assembly_game.processor import PROCESSOR_ACTIONS

# %%
MAX_STEPS = 20
env = gym.make("MinGame", max_episode_steps=MAX_STEPS, size=2)

# %%
model = PPO("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=150000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 18.1     |
# |    ep_rew_mean     | 0.27     |
# | time/              |          |
# |    fps             | 2951     |
# |    iterations      | 1        |
# |    time_elapsed    | 0        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 18.9        |
# |    ep_rew_mean          | 0.45        |
# | time/                   |             |
# |    fps                  | 2038        |
# |    iterations           | 2           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.014187114 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.32       |
# |    explained_variance   | -0.113      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0584      |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0437     |
# |    value_loss           | 0.146       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.2        |
# |    ep_rew_mean          | 2.01        |
# | time/                   |             |
# |    fps                  | 1889        |
# |    iterations           | 3           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.015428472 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.3        |
# |    explained_variance   | 0.0979      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0231     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0449     |
# |    value_loss           | 0.118       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19           |
# |    ep_rew_mean          | 1.24         |
# | time/                   |              |
# |    fps                  | 1827         |
# |    iterations           | 4            |
# |    time_elapsed         | 4            |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0068304967 |
# |    clip_fraction        | 0.0468       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.28        |
# |    explained_variance   | -0.00845     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.7          |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.0173      |
# |    value_loss           | 27.1         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.2        |
# |    ep_rew_mean          | 0.64        |
# | time/                   |             |
# |    fps                  | 1794        |
# |    iterations           | 5           |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009731822 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.26       |
# |    explained_variance   | -0.0204     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.12        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.022      |
# |    value_loss           | 7.63        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.5        |
# |    ep_rew_mean          | 3.44        |
# | time/                   |             |
# |    fps                  | 1766        |
# |    iterations           | 6           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.017908704 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.23       |
# |    explained_variance   | 0.204       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0606      |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.048      |
# |    value_loss           | 0.257       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.6        |
# |    ep_rew_mean          | 2.22        |
# | time/                   |             |
# |    fps                  | 1760        |
# |    iterations           | 7           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.005854948 |
# |    clip_fraction        | 0.0292      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.21       |
# |    explained_variance   | 0.00553     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 150         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0135     |
# |    value_loss           | 79.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.6        |
# |    ep_rew_mean          | 2.27        |
# | time/                   |             |
# |    fps                  | 1750        |
# |    iterations           | 8           |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.009245468 |
# |    clip_fraction        | 0.0606      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.18       |
# |    explained_variance   | 0.00863     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.686       |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0181     |
# |    value_loss           | 28.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 19.8         |
# |    ep_rew_mean          | 2.11         |
# | time/                   |              |
# |    fps                  | 1748         |
# |    iterations           | 9            |
# |    time_elapsed         | 10           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0098466575 |
# |    clip_fraction        | 0.0856       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -4.16        |
# |    explained_variance   | 0.00813      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 14.3         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.0182      |
# |    value_loss           | 32.3         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.6        |
# |    ep_rew_mean          | 1.69        |
# | time/                   |             |
# |    fps                  | 1736        |
# |    iterations           | 10          |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.011142742 |
# |    clip_fraction        | 0.119       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.0417      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.417       |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 19.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.9        |
# |    ep_rew_mean          | 1.85        |
# | time/                   |             |
# |    fps                  | 1734        |
# |    iterations           | 11          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.013215556 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.12       |
# |    explained_variance   | 0.11        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.26        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0253     |
# |    value_loss           | 11.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.6        |
# |    ep_rew_mean          | 4.11        |
# | time/                   |             |
# |    fps                  | 1730        |
# |    iterations           | 12          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.015309875 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.09       |
# |    explained_variance   | 0.0283      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 34.9        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0257     |
# |    value_loss           | 14.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.9        |
# |    ep_rew_mean          | 3.83        |
# | time/                   |             |
# |    fps                  | 1730        |
# |    iterations           | 13          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.010822745 |
# |    clip_fraction        | 0.0799      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -4.04       |
# |    explained_variance   | -0.0068     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.5        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 44.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 2.58        |
# | time/                   |             |
# |    fps                  | 1727        |
# |    iterations           | 14          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.013071367 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.99       |
# |    explained_variance   | 0.03        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24.1        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0212     |
# |    value_loss           | 60          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 6.86        |
# | time/                   |             |
# |    fps                  | 1725        |
# |    iterations           | 15          |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.014501483 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.95       |
# |    explained_variance   | 0.0405      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 37.3        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 28.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 6.66        |
# | time/                   |             |
# |    fps                  | 1723        |
# |    iterations           | 16          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.008188808 |
# |    clip_fraction        | 0.0459      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.94       |
# |    explained_variance   | 0.0341      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 21          |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0157     |
# |    value_loss           | 153         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 7.69        |
# | time/                   |             |
# |    fps                  | 1721        |
# |    iterations           | 17          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.011988038 |
# |    clip_fraction        | 0.0894      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.89       |
# |    explained_variance   | 0.0561      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 32.7        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0201     |
# |    value_loss           | 142         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.9        |
# |    ep_rew_mean          | 8.62        |
# | time/                   |             |
# |    fps                  | 1719        |
# |    iterations           | 18          |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.009509681 |
# |    clip_fraction        | 0.0662      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.82       |
# |    explained_variance   | 0.0384      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 71          |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0178     |
# |    value_loss           | 125         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.9        |
# |    ep_rew_mean          | 14.9        |
# | time/                   |             |
# |    fps                  | 1713        |
# |    iterations           | 19          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.012321242 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.75       |
# |    explained_variance   | 0.071       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 44.5        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0206     |
# |    value_loss           | 153         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 13.9        |
# | time/                   |             |
# |    fps                  | 1707        |
# |    iterations           | 20          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.007515764 |
# |    clip_fraction        | 0.0454      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.0651      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 141         |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0142     |
# |    value_loss           | 276         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.9        |
# |    ep_rew_mean          | 15.3        |
# | time/                   |             |
# |    fps                  | 1704        |
# |    iterations           | 21          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.008199414 |
# |    clip_fraction        | 0.044       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.101       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 43.1        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 245         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 15.9        |
# | time/                   |             |
# |    fps                  | 1697        |
# |    iterations           | 22          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.011026869 |
# |    clip_fraction        | 0.0822      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.56       |
# |    explained_variance   | 0.114       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 168         |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0187     |
# |    value_loss           | 294         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 19.8        |
# |    ep_rew_mean          | 24.9        |
# | time/                   |             |
# |    fps                  | 1692        |
# |    iterations           | 23          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.011212764 |
# |    clip_fraction        | 0.0643      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.49       |
# |    explained_variance   | 0.182       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 134         |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0188     |
# |    value_loss           | 284         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 28.1        |
# | time/                   |             |
# |    fps                  | 1690        |
# |    iterations           | 24          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.010749399 |
# |    clip_fraction        | 0.0719      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.38       |
# |    explained_variance   | 0.145       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 377         |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0169     |
# |    value_loss           | 506         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20         |
# |    ep_rew_mean          | 43.8       |
# | time/                   |            |
# |    fps                  | 1692       |
# |    iterations           | 25         |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 51200      |
# | train/                  |            |
# |    approx_kl            | 0.00999457 |
# |    clip_fraction        | 0.0639     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.24      |
# |    explained_variance   | 0.197      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 315        |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0184    |
# |    value_loss           | 570        |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 19.9       |
# |    ep_rew_mean          | 52.9       |
# | time/                   |            |
# |    fps                  | 1693       |
# |    iterations           | 26         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 53248      |
# | train/                  |            |
# |    approx_kl            | 0.01174227 |
# |    clip_fraction        | 0.0654     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.09      |
# |    explained_variance   | 0.227      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 460        |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.0168    |
# |    value_loss           | 822        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 63.8        |
# | time/                   |             |
# |    fps                  | 1692        |
# |    iterations           | 27          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.010011286 |
# |    clip_fraction        | 0.0544      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.91       |
# |    explained_variance   | 0.219       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 386         |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.0163     |
# |    value_loss           | 965         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 74.1        |
# | time/                   |             |
# |    fps                  | 1691        |
# |    iterations           | 28          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010896601 |
# |    clip_fraction        | 0.0453      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.76       |
# |    explained_variance   | 0.221       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 547         |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.015      |
# |    value_loss           | 1.19e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 83.7        |
# | time/                   |             |
# |    fps                  | 1691        |
# |    iterations           | 29          |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.011204032 |
# |    clip_fraction        | 0.0644      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.258       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 670         |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 1.48e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20         |
# |    ep_rew_mean          | 90.5       |
# | time/                   |            |
# |    fps                  | 1689       |
# |    iterations           | 30         |
# |    time_elapsed         | 36         |
# |    total_timesteps      | 61440      |
# | train/                  |            |
# |    approx_kl            | 0.00893187 |
# |    clip_fraction        | 0.0218     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.39      |
# |    explained_variance   | 0.282      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 871        |
# |    n_updates            | 290        |
# |    policy_gradient_loss | -0.0105    |
# |    value_loss           | 1.74e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20           |
# |    ep_rew_mean          | 93.8         |
# | time/                   |              |
# |    fps                  | 1687         |
# |    iterations           | 31           |
# |    time_elapsed         | 37           |
# |    total_timesteps      | 63488        |
# | train/                  |              |
# |    approx_kl            | 0.0062975604 |
# |    clip_fraction        | 0.0212       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.24        |
# |    explained_variance   | 0.332        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 914          |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -0.0103      |
# |    value_loss           | 1.78e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20           |
# |    ep_rew_mean          | 110          |
# | time/                   |              |
# |    fps                  | 1686         |
# |    iterations           | 32           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 65536        |
# | train/                  |              |
# |    approx_kl            | 0.0077031683 |
# |    clip_fraction        | 0.0361       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.12        |
# |    explained_variance   | 0.345        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 818          |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -0.011       |
# |    value_loss           | 2.01e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 125         |
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 33          |
# |    time_elapsed         | 40          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.009354525 |
# |    clip_fraction        | 0.0295      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.27        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.25e+03    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00905    |
# |    value_loss           | 2.34e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 129         |
# | time/                   |             |
# |    fps                  | 1685        |
# |    iterations           | 34          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.007991838 |
# |    clip_fraction        | 0.0228      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.92       |
# |    explained_variance   | 0.175       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08e+03    |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00787    |
# |    value_loss           | 2.74e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 133         |
# | time/                   |             |
# |    fps                  | 1685        |
# |    iterations           | 35          |
# |    time_elapsed         | 42          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.005381725 |
# |    clip_fraction        | 0.00498     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.83       |
# |    explained_variance   | 0.286       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+03    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 2.9e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 132         |
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 36          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.009017607 |
# |    clip_fraction        | 0.035       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | 0.153       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.00841    |
# |    value_loss           | 2.86e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 136         |
# | time/                   |             |
# |    fps                  | 1687        |
# |    iterations           | 37          |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.006560834 |
# |    clip_fraction        | 0.0159      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.6        |
# |    explained_variance   | 0.228       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.34e+03    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00722    |
# |    value_loss           | 2.87e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 20        |
# |    ep_rew_mean          | 144       |
# | time/                   |           |
# |    fps                  | 1688      |
# |    iterations           | 38        |
# |    time_elapsed         | 46        |
# |    total_timesteps      | 77824     |
# | train/                  |           |
# |    approx_kl            | 0.0108882 |
# |    clip_fraction        | 0.0736    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.59     |
# |    explained_variance   | 0.131     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.46e+03  |
# |    n_updates            | 370       |
# |    policy_gradient_loss | -0.0143   |
# |    value_loss           | 2.91e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 1689        |
# |    iterations           | 39          |
# |    time_elapsed         | 47          |
# |    total_timesteps      | 79872       |
# | train/                  |             |
# |    approx_kl            | 0.008380833 |
# |    clip_fraction        | 0.0452      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | 0.288       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35e+03    |
# |    n_updates            | 380         |
# |    policy_gradient_loss | -0.00805    |
# |    value_loss           | 3.2e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20           |
# |    ep_rew_mean          | 151          |
# | time/                   |              |
# |    fps                  | 1685         |
# |    iterations           | 40           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0073430515 |
# |    clip_fraction        | 0.0285       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.4         |
# |    explained_variance   | 0.201        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+03     |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00699     |
# |    value_loss           | 3.08e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 155         |
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 41          |
# |    time_elapsed         | 49          |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.010575489 |
# |    clip_fraction        | 0.0942      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.32       |
# |    explained_variance   | 0.165       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74e+03    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 3.24e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 20         |
# |    ep_rew_mean          | 153        |
# | time/                   |            |
# |    fps                  | 1687       |
# |    iterations           | 42         |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 86016      |
# | train/                  |            |
# |    approx_kl            | 0.00590773 |
# |    clip_fraction        | 0.0452     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.26      |
# |    explained_variance   | 0.0604     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.38e+03   |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.00686   |
# |    value_loss           | 3.29e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 20           |
# |    ep_rew_mean          | 158          |
# | time/                   |              |
# |    fps                  | 1687         |
# |    iterations           | 43           |
# |    time_elapsed         | 52           |
# |    total_timesteps      | 88064        |
# | train/                  |              |
# |    approx_kl            | 0.0035548967 |
# |    clip_fraction        | 0.00972      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.241        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.64e+03     |
# |    n_updates            | 420          |
# |    policy_gradient_loss | -0.00493     |
# |    value_loss           | 3.25e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 157         |
# | time/                   |             |
# |    fps                  | 1688        |
# |    iterations           | 44          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012127303 |
# |    clip_fraction        | 0.0568      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.14       |
# |    explained_variance   | 2.59e-05    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44e+03    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.00618    |
# |    value_loss           | 3.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 158         |
# | time/                   |             |
# |    fps                  | 1687        |
# |    iterations           | 45          |
# |    time_elapsed         | 54          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.010220041 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.242       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.59e+03    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00713    |
# |    value_loss           | 3.24e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 156         |
# | time/                   |             |
# |    fps                  | 1686        |
# |    iterations           | 46          |
# |    time_elapsed         | 55          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.011193266 |
# |    clip_fraction        | 0.0533      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.08       |
# |    explained_variance   | 0.194       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.44e+03    |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00672    |
# |    value_loss           | 3.22e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 165         |
# | time/                   |             |
# |    fps                  | 1687        |
# |    iterations           | 47          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.006479241 |
# |    clip_fraction        | 0.0723      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.238       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.4e+03     |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.00808    |
# |    value_loss           | 3.13e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 161         |
# | time/                   |             |
# |    fps                  | 1687        |
# |    iterations           | 48          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.007551149 |
# |    clip_fraction        | 0.0285      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.000386    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.3e+03     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.00215    |
# |    value_loss           | 3.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 20          |
# |    ep_rew_mean          | 165         |
# | time/                   |             |
# |    fps                  | 1688        |
# |    iterations           | 49          |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.006219876 |
# |    clip_fraction        | 0.0314      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.132       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.46e+03    |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.00427    |
# |    value_loss           | 3.12e+03    |
# -----------------------------------------

# %%
state, _ = env.reset()
cumreward = 0
for i in range(MAX_STEPS):
  action,_ = model.predict(state)
  state, reward, terminated, truncated, info = env.step(action)
  cumreward +=reward
  print(PROCESSOR_ACTIONS[action], info, reward)
  if terminated or truncated:
    print(terminated)
    print(truncated)
    print(f"Episode finished after {i+1} timestamps")
    break
print(f"total reward {cumreward}")
# Out:
# (<Instruction.MOV: 0>, <Operand.RSI: 1>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=0 rcx=0 cmp_res=0', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=0 cmp_res=0'} 1
# (<Instruction.MOV: 0>, <Operand.RDI: 0>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=0 rcx=1 cmp_res=0', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=0'} 0
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=2 rax=2 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 0
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 11
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.MOV: 0>, <Operand.RDI: 0>, <Operand.RCX: 3>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMP: 1>, <Operand.RDI: 0>, <Operand.RSI: 1>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# (<Instruction.CMOVG: 2>, <Operand.RDI: 0>, <Operand.RAX: 4>) {'example_0': 'rdi=1 rsi=2 rax=1 rdx=0 rcx=1 cmp_res=True', 'example_1': 'rdi=2 rsi=1 rax=1 rdx=0 rcx=2 cmp_res=False'} 10
# False
# True
# Episode finished after 20 timestamps
# total reward 172
